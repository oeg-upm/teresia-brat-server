# %% [markdown]
# # Estatuto Comun

# %%
base = "/Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion"

# %%
import os

paths = [i for i in os.listdir(base) if i not in [".DS_Store", "estatuto_comun"]]
print(paths)
# Out:
# ['dpej', 'termcat', 'recursos_mar', 'attentionRank']

# %% [markdown]
# # ANN

# %%
general = []
for i in paths:
    # Obtener la lista de archivos en el directorio
    archivos = os.listdir(base+"/"+i)
    general.append({
        "path": i,
        "archivos": [i for i in archivos if not i.endswith(".conf")]
    })

# %%
display(general)
# Out:
# [{'path': 'dpej',
#   'archivos': ['ejemplo_1_89.txt',
#    'ejemplo_1_59.ann',
#    'ejemplo_1_76.txt',
#    'ejemplo_1_65.ann',
#    'ejemplo_1_71.ann',
#    'ejemplo_1_62.txt',
#    'ejemplo_1_0.ann',
#    'ejemplo_1_7.txt',
#    'ejemplo_1_6.txt',
#    'ejemplo_1_1.ann',
#    'ejemplo_1_63.txt',
#    'ejemplo_1_70.ann',
#    'ejemplo_1_64.ann',
#    'ejemplo_1_77.txt',
#    'ejemplo_1_58.ann',
#    'ejemplo_1_88.txt',
#    'ejemplo_1_99.ann',
#    'ejemplo_1_49.txt',
#    'ejemplo_1_72.ann',
#    'ejemplo_1_61.txt',
#    'ejemplo_1_75.txt',
#    'ejemplo_1_66.ann',
#    'ejemplo_1_4.txt',
#    'ejemplo_1_3.ann',
#    'ejemplo_1_2.ann',
#    'ejemplo_1_5.txt',
#    'ejemplo_1_67.ann',
#    'ejemplo_1_74.txt',
#    'ejemplo_1_60.txt',
#    'ejemplo_1_73.ann',
#    'ejemplo_1_48.txt',
#    'ejemplo_1_98.ann',
#    'ejemplo_1_88.ann',
#    'ejemplo_1_77.ann',
#    'ejemplo_1_64.txt',
#    'ejemplo_1_70.txt',
#    'ejemplo_1_63.ann',
#    'ejemplo_1_58.txt',
#    'ejemplo_1_1.txt',
#    'ejemplo_1_6.ann',
#    'ejemplo_1_7.ann',
#    'ejemplo_1_0.txt',
#    'ejemplo_1_59.txt',
#    'ejemplo_1_62.ann',
#    'ejemplo_1_71.txt',
#    'ejemplo_1_65.txt',
#    'ejemplo_1_76.ann',
#    'ejemplo_1_89.ann',
#    'ejemplo_1_98.txt',
#    'ejemplo_1_73.txt',
#    'ejemplo_1_60.ann',
#    'ejemplo_1_74.ann',
#    'ejemplo_1_67.txt',
#    'ejemplo_1_48.ann',
#    'ejemplo_1_5.ann',
#    'ejemplo_1_2.txt',
#    'ejemplo_1_3.txt',
#    'ejemplo_1_4.ann',
#    'ejemplo_1_49.ann',
#    'ejemplo_1_66.txt',
#    'ejemplo_1_75.ann',
#    'ejemplo_1_61.ann',
#    'ejemplo_1_72.txt',
#    'ejemplo_1_99.txt',
#    'ejemplo_1_29.txt',
#    'ejemplo_1_15.txt',
#    'ejemplo_1_12.ann',
#    'ejemplo_1_116.ann',
#    'ejemplo_1_105.txt',
#    'ejemplo_1_111.txt',
#    'ejemplo_1_102.ann',
#    'ejemplo_1_139.txt',
#    'ejemplo_1_138.txt',
#    'ejemplo_1_103.ann',
#    'ejemplo_1_110.txt',
#    'ejemplo_1_104.txt',
#    'ejemplo_1_117.ann',
#    'ejemplo_1_13.ann',
#    'ejemplo_1_14.txt',
#    'ejemplo_1_28.txt',
#    'ejemplo_1_39.ann',
#    'ejemplo_1_11.ann',
#    'ejemplo_1_16.txt',
#    'ejemplo_1_112.txt',
#    'ejemplo_1_101.ann',
#    'ejemplo_1_115.ann',
#    'ejemplo_1_106.txt',
#    'ejemplo_1_129.ann',
#    'ejemplo_1_128.ann',
#    'ejemplo_1_107.txt',
#    'ejemplo_1_114.ann',
#    'ejemplo_1_100.ann',
#    'ejemplo_1_113.txt',
#    'ejemplo_1_17.txt',
#    'ejemplo_1_10.ann',
#    'ejemplo_1_38.ann',
#    'ejemplo_1_14.ann',
#    'ejemplo_1_13.txt',
#    'ejemplo_1_28.ann',
#    'ejemplo_1_138.ann',
#    'ejemplo_1_117.txt',
#    'ejemplo_1_104.ann',
#    'ejemplo_1_110.ann',
#    'ejemplo_1_103.txt',
#    'ejemplo_1_102.txt',
#    'ejemplo_1_111.ann',
#    'ejemplo_1_105.ann',
#    'ejemplo_1_116.txt',
#    'ejemplo_1_139.ann',
#    'ejemplo_1_29.ann',
#    'ejemplo_1_12.txt',
#    'ejemplo_1_15.ann',
#    'ejemplo_1_10.txt',
#    'ejemplo_1_17.ann',
#    'ejemplo_1_38.txt',
#    'ejemplo_1_128.txt',
#    'ejemplo_1_113.ann',
#    'ejemplo_1_100.txt',
#    'ejemplo_1_114.txt',
#    'ejemplo_1_107.ann',
#    'ejemplo_1_106.ann',
#    'ejemplo_1_115.txt',
#    'ejemplo_1_101.txt',
#    'ejemplo_1_112.ann',
#    'ejemplo_1_129.txt',
#    'ejemplo_1_39.txt',
#    'ejemplo_1_16.ann',
#    'ejemplo_1_11.txt',
#    'ejemplo_1_34.txt',
#    'ejemplo_1_27.ann',
#    'ejemplo_1_33.ann',
#    'ejemplo_1_20.txt',
#    'ejemplo_1_124.txt',
#    'ejemplo_1_137.ann',
#    'ejemplo_1_123.ann',
#    'ejemplo_1_130.txt',
#    'ejemplo_1_118.txt',
#    'ejemplo_1_119.txt',
#    'ejemplo_1_131.txt',
#    'ejemplo_1_122.ann',
#    'ejemplo_1_136.ann',
#    'ejemplo_1_125.txt',
#    'ejemplo_1_21.txt',
#    'ejemplo_1_32.ann',
#    'ejemplo_1_26.ann',
#    'ejemplo_1_35.txt',
#    'ejemplo_1_18.ann',
#    'ejemplo_1_30.ann',
#    'ejemplo_1_23.txt',
#    'ejemplo_1_37.txt',
#    'ejemplo_1_24.ann',
#    'ejemplo_1_120.ann',
#    'ejemplo_1_133.txt',
#    'ejemplo_1_127.txt',
#    'ejemplo_1_134.ann',
#    'ejemplo_1_108.ann',
#    'ejemplo_1_109.ann',
#    'ejemplo_1_135.ann',
#    'ejemplo_1_126.txt',
#    'ejemplo_1_132.txt',
#    'ejemplo_1_121.ann',
#    'ejemplo_1_25.ann',
#    'ejemplo_1_36.txt',
#    'ejemplo_1_22.txt',
#    'ejemplo_1_31.ann',
#    'ejemplo_1_19.ann',
#    'ejemplo_1_35.ann',
#    'ejemplo_1_26.txt',
#    'ejemplo_1_32.txt',
#    'ejemplo_1_21.ann',
#    'ejemplo_1_119.ann',
#    'ejemplo_1_125.ann',
#    'ejemplo_1_136.txt',
#    'ejemplo_1_122.txt',
#    'ejemplo_1_131.ann',
#    'ejemplo_1_130.ann',
#    'ejemplo_1_123.txt',
#    'ejemplo_1_137.txt',
#    'ejemplo_1_124.ann',
#    'ejemplo_1_118.ann',
#    'ejemplo_1_20.ann',
#    'ejemplo_1_33.txt',
#    'ejemplo_1_27.txt',
#    'ejemplo_1_34.ann',
#    'ejemplo_1_31.txt',
#    'ejemplo_1_22.ann',
#    'ejemplo_1_36.ann',
#    'ejemplo_1_25.txt',
#    'ejemplo_1_19.txt',
#    'ejemplo_1_109.txt',
#    'ejemplo_1_121.txt',
#    'ejemplo_1_132.ann',
#    'ejemplo_1_126.ann',
#    'ejemplo_1_135.txt',
#    'ejemplo_1_134.txt',
#    'ejemplo_1_127.ann',
#    'ejemplo_1_133.ann',
#    'ejemplo_1_120.txt',
#    'ejemplo_1_108.txt',
#    'ejemplo_1_18.txt',
#    'ejemplo_1_24.txt',
#    'ejemplo_1_37.ann',
#    'ejemplo_1_23.ann',
#    'ejemplo_1_30.txt',
#    'ejemplo_1_94.txt',
#    'ejemplo_1_87.ann',
#    'ejemplo_1_93.ann',
#    'ejemplo_1_80.txt',
#    'ejemplo_1_78.ann',
#    'ejemplo_1_44.ann',
#    'ejemplo_1_57.txt',
#    'ejemplo_1_43.txt',
#    'ejemplo_1_50.ann',
#    'ejemplo_1_9.ann',
#    'ejemplo_1_140.ann',
#    'ejemplo_1_8.ann',
#    'ejemplo_1_51.ann',
#    'ejemplo_1_42.txt',
#    'ejemplo_1_56.txt',
#    'ejemplo_1_45.ann',
#    'ejemplo_1_79.ann',
#    'ejemplo_1_81.txt',
#    'ejemplo_1_92.ann',
#    'ejemplo_1_86.ann',
#    'ejemplo_1_95.txt',
#    'ejemplo_1_90.ann',
#    'ejemplo_1_83.txt',
#    'ejemplo_1_97.txt',
#    'ejemplo_1_84.ann',
#    'ejemplo_1_68.txt',
#    'ejemplo_1_40.txt',
#    'ejemplo_1_53.ann',
#    'ejemplo_1_47.ann',
#    'ejemplo_1_54.txt',
#    'ejemplo_1_55.txt',
#    'ejemplo_1_46.ann',
#    'ejemplo_1_52.ann',
#    'ejemplo_1_41.txt',
#    'ejemplo_1_69.txt',
#    'ejemplo_1_85.ann',
#    'ejemplo_1_96.txt',
#    'ejemplo_1_82.txt',
#    'ejemplo_1_91.ann',
#    'ejemplo_1_95.ann',
#    'ejemplo_1_86.txt',
#    'ejemplo_1_92.txt',
#    'ejemplo_1_81.ann',
#    'ejemplo_1_45.txt',
#    'ejemplo_1_56.ann',
#    'ejemplo_1_42.ann',
#    'ejemplo_1_51.txt',
#    'ejemplo_1_79.txt',
#    'ejemplo_1_8.txt',
#    'ejemplo_1_140.txt',
#    'ejemplo_1_9.txt',
#    'ejemplo_1_78.txt',
#    'ejemplo_1_50.txt',
#    'ejemplo_1_43.ann',
#    'ejemplo_1_57.ann',
#    'ejemplo_1_44.txt',
#    'ejemplo_1_80.ann',
#    'ejemplo_1_93.txt',
#    'ejemplo_1_87.txt',
#    'ejemplo_1_94.ann',
#    'ejemplo_1_91.txt',
#    'ejemplo_1_82.ann',
#    'ejemplo_1_96.ann',
#    'ejemplo_1_85.txt',
#    'ejemplo_1_41.ann',
#    'ejemplo_1_52.txt',
#    'ejemplo_1_46.txt',
#    'ejemplo_1_55.ann',
#    'ejemplo_1_69.ann',
#    'ejemplo_1_68.ann',
#    'ejemplo_1_54.ann',
#    'ejemplo_1_47.txt',
#    'ejemplo_1_53.txt',
#    'ejemplo_1_40.ann',
#    'ejemplo_1_84.txt',
#    'ejemplo_1_97.ann',
#    'ejemplo_1_83.ann',
#    'ejemplo_1_90.txt']},
#  {'path': 'termcat',
#   'archivos': ['ejemplo_1_89.txt',
#    'ejemplo_1_59.ann',
#    'ejemplo_1_76.txt',
#    'ejemplo_1_65.ann',
#    'ejemplo_1_71.ann',
#    'ejemplo_1_62.txt',
#    'ejemplo_1_0.ann',
#    'ejemplo_1_7.txt',
#    'ejemplo_1_6.txt',
#    'ejemplo_1_1.ann',
#    'ejemplo_1_63.txt',
#    'ejemplo_1_70.ann',
#    'ejemplo_1_64.ann',
#    'ejemplo_1_77.txt',
#    'ejemplo_1_58.ann',
#    'ejemplo_1_88.txt',
#    'ejemplo_1_99.ann',
#    'ejemplo_1_49.txt',
#    'ejemplo_1_72.ann',
#    'ejemplo_1_61.txt',
#    'ejemplo_1_75.txt',
#    'ejemplo_1_66.ann',
#    'ejemplo_1_4.txt',
#    'ejemplo_1_3.ann',
#    'ejemplo_1_2.ann',
#    'ejemplo_1_5.txt',
#    'ejemplo_1_67.ann',
#    'ejemplo_1_74.txt',
#    'ejemplo_1_60.txt',
#    'ejemplo_1_73.ann',
#    'ejemplo_1_48.txt',
#    'ejemplo_1_98.ann',
#    'ejemplo_1_88.ann',
#    'ejemplo_1_77.ann',
#    'ejemplo_1_64.txt',
#    'ejemplo_1_70.txt',
#    'ejemplo_1_63.ann',
#    'ejemplo_1_58.txt',
#    'ejemplo_1_1.txt',
#    'ejemplo_1_6.ann',
#    'ejemplo_1_7.ann',
#    'ejemplo_1_0.txt',
#    'ejemplo_1_59.txt',
#    'ejemplo_1_62.ann',
#    'ejemplo_1_71.txt',
#    'ejemplo_1_65.txt',
#    'ejemplo_1_76.ann',
#    'ejemplo_1_89.ann',
#    'ejemplo_1_98.txt',
#    'ejemplo_1_73.txt',
#    'ejemplo_1_60.ann',
#    'ejemplo_1_74.ann',
#    'ejemplo_1_67.txt',
#    'ejemplo_1_48.ann',
#    'ejemplo_1_5.ann',
#    'ejemplo_1_2.txt',
#    'ejemplo_1_3.txt',
#    'ejemplo_1_4.ann',
#    'ejemplo_1_49.ann',
#    'ejemplo_1_66.txt',
#    'ejemplo_1_75.ann',
#    'ejemplo_1_61.ann',
#    'ejemplo_1_72.txt',
#    'ejemplo_1_99.txt',
#    'ejemplo_1_29.txt',
#    'ejemplo_1_15.txt',
#    'ejemplo_1_12.ann',
#    'ejemplo_1_116.ann',
#    'ejemplo_1_105.txt',
#    'ejemplo_1_111.txt',
#    'ejemplo_1_102.ann',
#    'ejemplo_1_139.txt',
#    'ejemplo_1_138.txt',
#    'ejemplo_1_103.ann',
#    'ejemplo_1_110.txt',
#    'ejemplo_1_104.txt',
#    'ejemplo_1_117.ann',
#    'ejemplo_1_13.ann',
#    'ejemplo_1_14.txt',
#    'ejemplo_1_28.txt',
#    'ejemplo_1_39.ann',
#    'ejemplo_1_11.ann',
#    'ejemplo_1_16.txt',
#    'ejemplo_1_112.txt',
#    'ejemplo_1_101.ann',
#    'ejemplo_1_115.ann',
#    'ejemplo_1_106.txt',
#    'ejemplo_1_129.ann',
#    'ejemplo_1_128.ann',
#    'ejemplo_1_107.txt',
#    'ejemplo_1_114.ann',
#    'ejemplo_1_100.ann',
#    'ejemplo_1_113.txt',
#    'ejemplo_1_17.txt',
#    'ejemplo_1_10.ann',
#    'ejemplo_1_38.ann',
#    'ejemplo_1_14.ann',
#    'ejemplo_1_13.txt',
#    'ejemplo_1_28.ann',
#    'ejemplo_1_138.ann',
#    'ejemplo_1_117.txt',
#    'ejemplo_1_104.ann',
#    'ejemplo_1_110.ann',
#    'ejemplo_1_103.txt',
#    'ejemplo_1_102.txt',
#    'ejemplo_1_111.ann',
#    'ejemplo_1_105.ann',
#    'ejemplo_1_116.txt',
#    'ejemplo_1_139.ann',
#    'ejemplo_1_29.ann',
#    'ejemplo_1_12.txt',
#    'ejemplo_1_15.ann',
#    'ejemplo_1_10.txt',
#    'ejemplo_1_17.ann',
#    'ejemplo_1_38.txt',
#    'ejemplo_1_128.txt',
#    'ejemplo_1_113.ann',
#    'ejemplo_1_100.txt',
#    'ejemplo_1_114.txt',
#    'ejemplo_1_107.ann',
#    'ejemplo_1_106.ann',
#    'ejemplo_1_115.txt',
#    'ejemplo_1_101.txt',
#    'ejemplo_1_112.ann',
#    'ejemplo_1_129.txt',
#    'ejemplo_1_39.txt',
#    'ejemplo_1_16.ann',
#    'ejemplo_1_11.txt',
#    'ejemplo_1_34.txt',
#    'ejemplo_1_27.ann',
#    'ejemplo_1_33.ann',
#    'ejemplo_1_20.txt',
#    'ejemplo_1_124.txt',
#    'ejemplo_1_137.ann',
#    'ejemplo_1_123.ann',
#    'ejemplo_1_130.txt',
#    'ejemplo_1_118.txt',
#    'ejemplo_1_119.txt',
#    'ejemplo_1_131.txt',
#    'ejemplo_1_122.ann',
#    'ejemplo_1_136.ann',
#    'ejemplo_1_125.txt',
#    'ejemplo_1_21.txt',
#    'ejemplo_1_32.ann',
#    'ejemplo_1_26.ann',
#    'ejemplo_1_35.txt',
#    'ejemplo_1_18.ann',
#    'ejemplo_1_30.ann',
#    'ejemplo_1_23.txt',
#    'ejemplo_1_37.txt',
#    'ejemplo_1_24.ann',
#    'ejemplo_1_120.ann',
#    'ejemplo_1_133.txt',
#    'ejemplo_1_127.txt',
#    'ejemplo_1_134.ann',
#    'ejemplo_1_108.ann',
#    'ejemplo_1_109.ann',
#    'ejemplo_1_135.ann',
#    'ejemplo_1_126.txt',
#    'ejemplo_1_132.txt',
#    'ejemplo_1_121.ann',
#    'ejemplo_1_25.ann',
#    'ejemplo_1_36.txt',
#    'ejemplo_1_22.txt',
#    'ejemplo_1_31.ann',
#    'ejemplo_1_19.ann',
#    'ejemplo_1_35.ann',
#    'ejemplo_1_26.txt',
#    'ejemplo_1_32.txt',
#    'ejemplo_1_21.ann',
#    'ejemplo_1_119.ann',
#    'ejemplo_1_125.ann',
#    'ejemplo_1_136.txt',
#    'ejemplo_1_122.txt',
#    'ejemplo_1_131.ann',
#    'ejemplo_1_130.ann',
#    'ejemplo_1_123.txt',
#    'ejemplo_1_137.txt',
#    'ejemplo_1_124.ann',
#    'ejemplo_1_118.ann',
#    'ejemplo_1_20.ann',
#    'ejemplo_1_33.txt',
#    'ejemplo_1_27.txt',
#    'ejemplo_1_34.ann',
#    'ejemplo_1_31.txt',
#    'ejemplo_1_22.ann',
#    'ejemplo_1_36.ann',
#    'ejemplo_1_25.txt',
#    'ejemplo_1_19.txt',
#    'ejemplo_1_109.txt',
#    'ejemplo_1_121.txt',
#    'ejemplo_1_132.ann',
#    'ejemplo_1_126.ann',
#    'ejemplo_1_135.txt',
#    'ejemplo_1_134.txt',
#    'ejemplo_1_127.ann',
#    'ejemplo_1_133.ann',
#    'ejemplo_1_120.txt',
#    'ejemplo_1_108.txt',
#    'ejemplo_1_18.txt',
#    'ejemplo_1_24.txt',
#    'ejemplo_1_37.ann',
#    'ejemplo_1_23.ann',
#    'ejemplo_1_30.txt',
#    'ejemplo_1_94.txt',
#    'ejemplo_1_87.ann',
#    'ejemplo_1_93.ann',
#    'ejemplo_1_80.txt',
#    'ejemplo_1_78.ann',
#    'ejemplo_1_44.ann',
#    'ejemplo_1_57.txt',
#    'ejemplo_1_43.txt',
#    'ejemplo_1_50.ann',
#    'ejemplo_1_9.ann',
#    'ejemplo_1_140.ann',
#    'ejemplo_1_8.ann',
#    'ejemplo_1_51.ann',
#    'ejemplo_1_42.txt',
#    'ejemplo_1_56.txt',
#    'ejemplo_1_45.ann',
#    'ejemplo_1_79.ann',
#    'ejemplo_1_81.txt',
#    'ejemplo_1_92.ann',
#    'ejemplo_1_86.ann',
#    'ejemplo_1_95.txt',
#    'ejemplo_1_90.ann',
#    'ejemplo_1_83.txt',
#    'ejemplo_1_97.txt',
#    'ejemplo_1_84.ann',
#    'ejemplo_1_68.txt',
#    'ejemplo_1_40.txt',
#    'ejemplo_1_53.ann',
#    'ejemplo_1_47.ann',
#    'ejemplo_1_54.txt',
#    'ejemplo_1_55.txt',
#    'ejemplo_1_46.ann',
#    'ejemplo_1_52.ann',
#    'ejemplo_1_41.txt',
#    'ejemplo_1_69.txt',
#    'ejemplo_1_85.ann',
#    'ejemplo_1_96.txt',
#    'ejemplo_1_82.txt',
#    'ejemplo_1_91.ann',
#    'ejemplo_1_95.ann',
#    'ejemplo_1_86.txt',
#    'ejemplo_1_92.txt',
#    'ejemplo_1_81.ann',
#    'ejemplo_1_45.txt',
#    'ejemplo_1_56.ann',
#    'ejemplo_1_42.ann',
#    'ejemplo_1_51.txt',
#    'ejemplo_1_79.txt',
#    'ejemplo_1_8.txt',
#    'ejemplo_1_140.txt',
#    'ejemplo_1_9.txt',
#    'ejemplo_1_78.txt',
#    'ejemplo_1_50.txt',
#    'ejemplo_1_43.ann',
#    'ejemplo_1_57.ann',
#    'ejemplo_1_44.txt',
#    'ejemplo_1_80.ann',
#    'ejemplo_1_93.txt',
#    'ejemplo_1_87.txt',
#    'ejemplo_1_94.ann',
#    'ejemplo_1_91.txt',
#    'ejemplo_1_82.ann',
#    'ejemplo_1_96.ann',
#    'ejemplo_1_85.txt',
#    'ejemplo_1_41.ann',
#    'ejemplo_1_52.txt',
#    'ejemplo_1_46.txt',
#    'ejemplo_1_55.ann',
#    'ejemplo_1_69.ann',
#    'ejemplo_1_68.ann',
#    'ejemplo_1_54.ann',
#    'ejemplo_1_47.txt',
#    'ejemplo_1_53.txt',
#    'ejemplo_1_40.ann',
#    'ejemplo_1_84.txt',
#    'ejemplo_1_97.ann',
#    'ejemplo_1_83.ann',
#    'ejemplo_1_90.txt']},
#  {'path': 'recursos_mar',
#   'archivos': ['ejemplo_1_89.txt',
#    'ejemplo_1_59.ann',
#    'ejemplo_1_76.txt',
#    'ejemplo_1_65.ann',
#    'ejemplo_1_71.ann',
#    'ejemplo_1_62.txt',
#    'ejemplo_1_0.ann',
#    'ejemplo_1_7.txt',
#    'ejemplo_1_6.txt',
#    'ejemplo_1_1.ann',
#    'ejemplo_1_63.txt',
#    'ejemplo_1_70.ann',
#    'ejemplo_1_64.ann',
#    'ejemplo_1_77.txt',
#    'ejemplo_1_58.ann',
#    'ejemplo_1_88.txt',
#    'ejemplo_1_99.ann',
#    'ejemplo_1_49.txt',
#    'ejemplo_1_72.ann',
#    'ejemplo_1_61.txt',
#    'ejemplo_1_75.txt',
#    'ejemplo_1_66.ann',
#    'ejemplo_1_4.txt',
#    'ejemplo_1_3.ann',
#    'ejemplo_1_2.ann',
#    'ejemplo_1_5.txt',
#    'ejemplo_1_67.ann',
#    'ejemplo_1_74.txt',
#    'ejemplo_1_60.txt',
#    'ejemplo_1_73.ann',
#    'ejemplo_1_48.txt',
#    'ejemplo_1_98.ann',
#    'ejemplo_1_88.ann',
#    'ejemplo_1_77.ann',
#    'ejemplo_1_64.txt',
#    'ejemplo_1_70.txt',
#    'ejemplo_1_63.ann',
#    'ejemplo_1_58.txt',
#    'ejemplo_1_1.txt',
#    'ejemplo_1_6.ann',
#    'ejemplo_1_7.ann',
#    'ejemplo_1_0.txt',
#    'ejemplo_1_59.txt',
#    'ejemplo_1_62.ann',
#    'ejemplo_1_71.txt',
#    'ejemplo_1_65.txt',
#    'ejemplo_1_76.ann',
#    'ejemplo_1_89.ann',
#    'ejemplo_1_98.txt',
#    'ejemplo_1_73.txt',
#    'ejemplo_1_60.ann',
#    'ejemplo_1_74.ann',
#    'ejemplo_1_67.txt',
#    'ejemplo_1_48.ann',
#    'ejemplo_1_5.ann',
#    'ejemplo_1_2.txt',
#    'ejemplo_1_3.txt',
#    'ejemplo_1_4.ann',
#    'ejemplo_1_49.ann',
#    'ejemplo_1_66.txt',
#    'ejemplo_1_75.ann',
#    'ejemplo_1_61.ann',
#    'ejemplo_1_72.txt',
#    'ejemplo_1_99.txt',
#    'ejemplo_1_29.txt',
#    'ejemplo_1_15.txt',
#    'ejemplo_1_12.ann',
#    'ejemplo_1_116.ann',
#    'ejemplo_1_105.txt',
#    'ejemplo_1_111.txt',
#    'ejemplo_1_102.ann',
#    'ejemplo_1_139.txt',
#    'ejemplo_1_138.txt',
#    'ejemplo_1_103.ann',
#    'ejemplo_1_110.txt',
#    'ejemplo_1_104.txt',
#    'ejemplo_1_117.ann',
#    'ejemplo_1_13.ann',
#    'ejemplo_1_14.txt',
#    'ejemplo_1_28.txt',
#    'ejemplo_1_39.ann',
#    'ejemplo_1_11.ann',
#    'ejemplo_1_16.txt',
#    'ejemplo_1_112.txt',
#    'ejemplo_1_101.ann',
#    'ejemplo_1_115.ann',
#    'ejemplo_1_106.txt',
#    'ejemplo_1_129.ann',
#    'ejemplo_1_128.ann',
#    'ejemplo_1_107.txt',
#    'ejemplo_1_114.ann',
#    'ejemplo_1_100.ann',
#    'ejemplo_1_113.txt',
#    'ejemplo_1_17.txt',
#    'ejemplo_1_10.ann',
#    'ejemplo_1_38.ann',
#    'ejemplo_1_14.ann',
#    'ejemplo_1_13.txt',
#    'ejemplo_1_28.ann',
#    'ejemplo_1_138.ann',
#    'ejemplo_1_117.txt',
#    'ejemplo_1_104.ann',
#    'ejemplo_1_110.ann',
#    'ejemplo_1_103.txt',
#    'ejemplo_1_102.txt',
#    'ejemplo_1_111.ann',
#    'ejemplo_1_105.ann',
#    'ejemplo_1_116.txt',
#    'ejemplo_1_139.ann',
#    'ejemplo_1_29.ann',
#    'ejemplo_1_12.txt',
#    'ejemplo_1_15.ann',
#    'ejemplo_1_10.txt',
#    'ejemplo_1_17.ann',
#    'ejemplo_1_38.txt',
#    'ejemplo_1_128.txt',
#    'ejemplo_1_113.ann',
#    'ejemplo_1_100.txt',
#    'ejemplo_1_114.txt',
#    'ejemplo_1_107.ann',
#    'ejemplo_1_106.ann',
#    'ejemplo_1_115.txt',
#    'ejemplo_1_101.txt',
#    'ejemplo_1_112.ann',
#    'ejemplo_1_129.txt',
#    'ejemplo_1_39.txt',
#    'ejemplo_1_16.ann',
#    'ejemplo_1_11.txt',
#    'ejemplo_1_34.txt',
#    'ejemplo_1_27.ann',
#    'ejemplo_1_33.ann',
#    'ejemplo_1_20.txt',
#    'ejemplo_1_124.txt',
#    'ejemplo_1_137.ann',
#    'ejemplo_1_123.ann',
#    'ejemplo_1_130.txt',
#    'ejemplo_1_118.txt',
#    'ejemplo_1_119.txt',
#    'ejemplo_1_131.txt',
#    'ejemplo_1_122.ann',
#    'ejemplo_1_136.ann',
#    'ejemplo_1_125.txt',
#    'ejemplo_1_21.txt',
#    'ejemplo_1_32.ann',
#    'ejemplo_1_26.ann',
#    'ejemplo_1_35.txt',
#    'ejemplo_1_18.ann',
#    'ejemplo_1_30.ann',
#    'ejemplo_1_23.txt',
#    'ejemplo_1_37.txt',
#    'ejemplo_1_24.ann',
#    'ejemplo_1_120.ann',
#    'ejemplo_1_133.txt',
#    'ejemplo_1_127.txt',
#    'ejemplo_1_134.ann',
#    'ejemplo_1_108.ann',
#    'ejemplo_1_109.ann',
#    'ejemplo_1_135.ann',
#    'ejemplo_1_126.txt',
#    'ejemplo_1_132.txt',
#    'ejemplo_1_121.ann',
#    'ejemplo_1_25.ann',
#    'ejemplo_1_36.txt',
#    'ejemplo_1_22.txt',
#    'ejemplo_1_31.ann',
#    'ejemplo_1_19.ann',
#    'ejemplo_1_35.ann',
#    'ejemplo_1_26.txt',
#    'ejemplo_1_32.txt',
#    'ejemplo_1_21.ann',
#    'ejemplo_1_119.ann',
#    'ejemplo_1_125.ann',
#    'ejemplo_1_136.txt',
#    'ejemplo_1_122.txt',
#    'ejemplo_1_131.ann',
#    'ejemplo_1_130.ann',
#    'ejemplo_1_123.txt',
#    'ejemplo_1_137.txt',
#    'ejemplo_1_124.ann',
#    'ejemplo_1_118.ann',
#    'ejemplo_1_20.ann',
#    'ejemplo_1_33.txt',
#    'ejemplo_1_27.txt',
#    'ejemplo_1_34.ann',
#    'ejemplo_1_31.txt',
#    'ejemplo_1_22.ann',
#    'ejemplo_1_36.ann',
#    'ejemplo_1_25.txt',
#    'ejemplo_1_19.txt',
#    'ejemplo_1_109.txt',
#    'ejemplo_1_121.txt',
#    'ejemplo_1_132.ann',
#    'ejemplo_1_126.ann',
#    'ejemplo_1_135.txt',
#    'ejemplo_1_134.txt',
#    'ejemplo_1_127.ann',
#    'ejemplo_1_133.ann',
#    'ejemplo_1_120.txt',
#    'ejemplo_1_108.txt',
#    'ejemplo_1_18.txt',
#    'ejemplo_1_24.txt',
#    'ejemplo_1_37.ann',
#    'ejemplo_1_23.ann',
#    'ejemplo_1_30.txt',
#    'ejemplo_1_94.txt',
#    'ejemplo_1_87.ann',
#    'ejemplo_1_93.ann',
#    'ejemplo_1_80.txt',
#    'ejemplo_1_78.ann',
#    'ejemplo_1_44.ann',
#    'ejemplo_1_57.txt',
#    'ejemplo_1_43.txt',
#    'ejemplo_1_50.ann',
#    'ejemplo_1_9.ann',
#    'ejemplo_1_140.ann',
#    'ejemplo_1_8.ann',
#    'ejemplo_1_51.ann',
#    'ejemplo_1_42.txt',
#    'ejemplo_1_56.txt',
#    'ejemplo_1_45.ann',
#    'ejemplo_1_79.ann',
#    'ejemplo_1_81.txt',
#    'ejemplo_1_92.ann',
#    'ejemplo_1_86.ann',
#    'ejemplo_1_95.txt',
#    'ejemplo_1_90.ann',
#    'ejemplo_1_83.txt',
#    'ejemplo_1_97.txt',
#    'ejemplo_1_84.ann',
#    'ejemplo_1_68.txt',
#    'ejemplo_1_40.txt',
#    'ejemplo_1_53.ann',
#    'ejemplo_1_47.ann',
#    'ejemplo_1_54.txt',
#    'ejemplo_1_55.txt',
#    'ejemplo_1_46.ann',
#    'ejemplo_1_52.ann',
#    'ejemplo_1_41.txt',
#    'ejemplo_1_69.txt',
#    'ejemplo_1_85.ann',
#    'ejemplo_1_96.txt',
#    'ejemplo_1_82.txt',
#    'ejemplo_1_91.ann',
#    'ejemplo_1_95.ann',
#    'ejemplo_1_86.txt',
#    'ejemplo_1_92.txt',
#    'ejemplo_1_81.ann',
#    'ejemplo_1_45.txt',
#    'ejemplo_1_56.ann',
#    'ejemplo_1_42.ann',
#    'ejemplo_1_51.txt',
#    'ejemplo_1_79.txt',
#    'ejemplo_1_8.txt',
#    'ejemplo_1_140.txt',
#    'ejemplo_1_9.txt',
#    'ejemplo_1_78.txt',
#    'ejemplo_1_50.txt',
#    'ejemplo_1_43.ann',
#    'ejemplo_1_57.ann',
#    'ejemplo_1_44.txt',
#    'ejemplo_1_80.ann',
#    'ejemplo_1_93.txt',
#    'ejemplo_1_87.txt',
#    'ejemplo_1_94.ann',
#    'ejemplo_1_91.txt',
#    'ejemplo_1_82.ann',
#    'ejemplo_1_96.ann',
#    'ejemplo_1_85.txt',
#    'ejemplo_1_41.ann',
#    'ejemplo_1_52.txt',
#    'ejemplo_1_46.txt',
#    'ejemplo_1_55.ann',
#    'ejemplo_1_69.ann',
#    'ejemplo_1_68.ann',
#    'ejemplo_1_54.ann',
#    'ejemplo_1_47.txt',
#    'ejemplo_1_53.txt',
#    'ejemplo_1_40.ann',
#    'ejemplo_1_84.txt',
#    'ejemplo_1_97.ann',
#    'ejemplo_1_83.ann',
#    'ejemplo_1_90.txt']},
#  {'path': 'attentionRank',
#   'archivos': ['ejemplo_1_89.txt',
#    'ejemplo_1_59.ann',
#    'ejemplo_1_76.txt',
#    'ejemplo_1_65.ann',
#    'ejemplo_1_71.ann',
#    'ejemplo_1_62.txt',
#    'ejemplo_1_0.ann',
#    'ejemplo_1_7.txt',
#    'ejemplo_1_6.txt',
#    'ejemplo_1_1.ann',
#    'ejemplo_1_63.txt',
#    'ejemplo_1_70.ann',
#    'ejemplo_1_64.ann',
#    'ejemplo_1_77.txt',
#    'ejemplo_1_58.ann',
#    'ejemplo_1_88.txt',
#    'ejemplo_1_99.ann',
#    'ejemplo_1_49.txt',
#    'ejemplo_1_72.ann',
#    'ejemplo_1_61.txt',
#    'ejemplo_1_75.txt',
#    'ejemplo_1_66.ann',
#    'ejemplo_1_4.txt',
#    'ejemplo_1_3.ann',
#    'ejemplo_1_2.ann',
#    'ejemplo_1_5.txt',
#    'ejemplo_1_67.ann',
#    'ejemplo_1_74.txt',
#    'ejemplo_1_60.txt',
#    'ejemplo_1_73.ann',
#    'ejemplo_1_48.txt',
#    'ejemplo_1_98.ann',
#    'ejemplo_1_88.ann',
#    'ejemplo_1_77.ann',
#    'ejemplo_1_64.txt',
#    'ejemplo_1_70.txt',
#    'ejemplo_1_63.ann',
#    'ejemplo_1_58.txt',
#    'ejemplo_1_1.txt',
#    'ejemplo_1_6.ann',
#    'ejemplo_1_7.ann',
#    'ejemplo_1_0.txt',
#    'ejemplo_1_59.txt',
#    'ejemplo_1_62.ann',
#    'ejemplo_1_71.txt',
#    'ejemplo_1_65.txt',
#    'ejemplo_1_76.ann',
#    'ejemplo_1_89.ann',
#    'ejemplo_1_98.txt',
#    'ejemplo_1_73.txt',
#    'ejemplo_1_60.ann',
#    'ejemplo_1_74.ann',
#    'ejemplo_1_67.txt',
#    'ejemplo_1_48.ann',
#    'ejemplo_1_5.ann',
#    'ejemplo_1_2.txt',
#    'ejemplo_1_3.txt',
#    'ejemplo_1_4.ann',
#    'ejemplo_1_49.ann',
#    'ejemplo_1_66.txt',
#    'ejemplo_1_75.ann',
#    'ejemplo_1_61.ann',
#    'ejemplo_1_72.txt',
#    'ejemplo_1_99.txt',
#    'ejemplo_1_29.txt',
#    'ejemplo_1_15.txt',
#    'ejemplo_1_12.ann',
#    'ejemplo_1_116.ann',
#    'ejemplo_1_105.txt',
#    'ejemplo_1_111.txt',
#    'ejemplo_1_102.ann',
#    'ejemplo_1_139.txt',
#    'ejemplo_1_138.txt',
#    'ejemplo_1_103.ann',
#    'ejemplo_1_110.txt',
#    'ejemplo_1_104.txt',
#    'ejemplo_1_117.ann',
#    'ejemplo_1_13.ann',
#    'ejemplo_1_14.txt',
#    'ejemplo_1_28.txt',
#    'ejemplo_1_39.ann',
#    'ejemplo_1_11.ann',
#    'ejemplo_1_16.txt',
#    'ejemplo_1_112.txt',
#    'ejemplo_1_101.ann',
#    'ejemplo_1_115.ann',
#    'ejemplo_1_106.txt',
#    'ejemplo_1_129.ann',
#    'ejemplo_1_128.ann',
#    'ejemplo_1_107.txt',
#    'ejemplo_1_114.ann',
#    'ejemplo_1_100.ann',
#    'ejemplo_1_113.txt',
#    'ejemplo_1_17.txt',
#    'ejemplo_1_10.ann',
#    'ejemplo_1_38.ann',
#    'ejemplo_1_14.ann',
#    'ejemplo_1_13.txt',
#    'ejemplo_1_28.ann',
#    'ejemplo_1_138.ann',
#    'ejemplo_1_117.txt',
#    'ejemplo_1_104.ann',
#    'ejemplo_1_110.ann',
#    'ejemplo_1_103.txt',
#    'ejemplo_1_102.txt',
#    'ejemplo_1_111.ann',
#    'ejemplo_1_105.ann',
#    'ejemplo_1_116.txt',
#    'ejemplo_1_139.ann',
#    'ejemplo_1_29.ann',
#    'ejemplo_1_12.txt',
#    'ejemplo_1_15.ann',
#    'ejemplo_1_10.txt',
#    'ejemplo_1_17.ann',
#    'ejemplo_1_38.txt',
#    'ejemplo_1_128.txt',
#    'ejemplo_1_113.ann',
#    'ejemplo_1_100.txt',
#    'ejemplo_1_114.txt',
#    'ejemplo_1_107.ann',
#    'ejemplo_1_106.ann',
#    'ejemplo_1_115.txt',
#    'ejemplo_1_101.txt',
#    'ejemplo_1_112.ann',
#    'ejemplo_1_129.txt',
#    'ejemplo_1_39.txt',
#    'ejemplo_1_16.ann',
#    'ejemplo_1_11.txt',
#    'ejemplo_1_34.txt',
#    'ejemplo_1_27.ann',
#    'ejemplo_1_33.ann',
#    'ejemplo_1_20.txt',
#    'ejemplo_1_124.txt',
#    'ejemplo_1_137.ann',
#    'ejemplo_1_123.ann',
#    'ejemplo_1_130.txt',
#    'ejemplo_1_118.txt',
#    'ejemplo_1_119.txt',
#    'ejemplo_1_131.txt',
#    'ejemplo_1_122.ann',
#    'ejemplo_1_136.ann',
#    'ejemplo_1_125.txt',
#    'ejemplo_1_21.txt',
#    'ejemplo_1_32.ann',
#    'ejemplo_1_26.ann',
#    'ejemplo_1_35.txt',
#    'ejemplo_1_18.ann',
#    'ejemplo_1_30.ann',
#    'ejemplo_1_23.txt',
#    'ejemplo_1_37.txt',
#    'ejemplo_1_24.ann',
#    'ejemplo_1_120.ann',
#    'ejemplo_1_133.txt',
#    'ejemplo_1_127.txt',
#    'ejemplo_1_134.ann',
#    'ejemplo_1_108.ann',
#    'ejemplo_1_109.ann',
#    'ejemplo_1_135.ann',
#    'ejemplo_1_126.txt',
#    'ejemplo_1_132.txt',
#    'ejemplo_1_121.ann',
#    'ejemplo_1_25.ann',
#    'ejemplo_1_36.txt',
#    'ejemplo_1_22.txt',
#    'ejemplo_1_31.ann',
#    'ejemplo_1_19.ann',
#    'ejemplo_1_35.ann',
#    'ejemplo_1_26.txt',
#    'ejemplo_1_32.txt',
#    'ejemplo_1_21.ann',
#    'ejemplo_1_119.ann',
#    'ejemplo_1_125.ann',
#    'ejemplo_1_136.txt',
#    'ejemplo_1_122.txt',
#    'ejemplo_1_131.ann',
#    'ejemplo_1_130.ann',
#    'ejemplo_1_123.txt',
#    'ejemplo_1_137.txt',
#    'ejemplo_1_124.ann',
#    'ejemplo_1_118.ann',
#    'ejemplo_1_20.ann',
#    'ejemplo_1_33.txt',
#    'ejemplo_1_27.txt',
#    'ejemplo_1_34.ann',
#    'ejemplo_1_31.txt',
#    'ejemplo_1_22.ann',
#    'ejemplo_1_36.ann',
#    'ejemplo_1_25.txt',
#    'ejemplo_1_19.txt',
#    'ejemplo_1_109.txt',
#    'ejemplo_1_121.txt',
#    'ejemplo_1_132.ann',
#    'ejemplo_1_126.ann',
#    'ejemplo_1_135.txt',
#    'ejemplo_1_134.txt',
#    'ejemplo_1_127.ann',
#    'ejemplo_1_133.ann',
#    'ejemplo_1_120.txt',
#    'ejemplo_1_108.txt',
#    'ejemplo_1_18.txt',
#    'ejemplo_1_24.txt',
#    'ejemplo_1_37.ann',
#    'ejemplo_1_23.ann',
#    'ejemplo_1_30.txt',
#    'ejemplo_1_94.txt',
#    'ejemplo_1_87.ann',
#    'ejemplo_1_93.ann',
#    'ejemplo_1_80.txt',
#    'ejemplo_1_78.ann',
#    'ejemplo_1_44.ann',
#    'ejemplo_1_57.txt',
#    'ejemplo_1_43.txt',
#    'ejemplo_1_50.ann',
#    'ejemplo_1_9.ann',
#    'ejemplo_1_140.ann',
#    'ejemplo_1_8.ann',
#    'ejemplo_1_51.ann',
#    'ejemplo_1_42.txt',
#    'ejemplo_1_56.txt',
#    'ejemplo_1_45.ann',
#    'ejemplo_1_79.ann',
#    'ejemplo_1_81.txt',
#    'ejemplo_1_92.ann',
#    'ejemplo_1_86.ann',
#    'ejemplo_1_95.txt',
#    'ejemplo_1_90.ann',
#    'ejemplo_1_83.txt',
#    'ejemplo_1_97.txt',
#    'ejemplo_1_84.ann',
#    'ejemplo_1_68.txt',
#    'ejemplo_1_40.txt',
#    'ejemplo_1_53.ann',
#    'ejemplo_1_47.ann',
#    'ejemplo_1_54.txt',
#    'ejemplo_1_55.txt',
#    'ejemplo_1_46.ann',
#    'ejemplo_1_52.ann',
#    'ejemplo_1_41.txt',
#    'ejemplo_1_69.txt',
#    'ejemplo_1_85.ann',
#    'ejemplo_1_96.txt',
#    'ejemplo_1_82.txt',
#    'ejemplo_1_91.ann',
#    'ejemplo_1_95.ann',
#    'ejemplo_1_86.txt',
#    'ejemplo_1_92.txt',
#    'ejemplo_1_81.ann',
#    'ejemplo_1_45.txt',
#    'ejemplo_1_56.ann',
#    'ejemplo_1_42.ann',
#    'ejemplo_1_51.txt',
#    'ejemplo_1_79.txt',
#    'ejemplo_1_8.txt',
#    'ejemplo_1_140.txt',
#    'ejemplo_1_9.txt',
#    'ejemplo_1_78.txt',
#    'ejemplo_1_50.txt',
#    'ejemplo_1_43.ann',
#    'ejemplo_1_57.ann',
#    'ejemplo_1_44.txt',
#    'ejemplo_1_80.ann',
#    'ejemplo_1_93.txt',
#    'ejemplo_1_87.txt',
#    'ejemplo_1_94.ann',
#    'ejemplo_1_91.txt',
#    'ejemplo_1_82.ann',
#    'ejemplo_1_96.ann',
#    'ejemplo_1_85.txt',
#    'ejemplo_1_41.ann',
#    'ejemplo_1_52.txt',
#    'ejemplo_1_46.txt',
#    'ejemplo_1_55.ann',
#    'ejemplo_1_69.ann',
#    'ejemplo_1_68.ann',
#    'ejemplo_1_54.ann',
#    'ejemplo_1_47.txt',
#    'ejemplo_1_53.txt',
#    'ejemplo_1_40.ann',
#    'ejemplo_1_84.txt',
#    'ejemplo_1_97.ann',
#    'ejemplo_1_83.ann',
#    'ejemplo_1_90.txt']}]

# %%
import pandas as pd

# Función para verificar si un archivo .ann tiene contenido
def check_ann_file_content(path, file):
    try:
        full_path = base+"/"+path+"/"+file
        return os.path.getsize(full_path) > 0
        
    except FileNotFoundError:
        return False

# Creación de una lista para construir el DataFrame
data_list = []

for item in general:
    path = item['path']
    ann_files = [file for file in item['archivos'] if file.endswith('.ann')]
    for ann_file in ann_files:
        has_content = check_ann_file_content(path, ann_file)
        data_list.append([path, ann_file, has_content])

# %%
# Creación del DataFrame
df = pd.DataFrame(data_list, columns=['path', 'ann_file', 'has_content'])
display(df)
# Out:
#               path          ann_file  has_content
# 0             dpej  ejemplo_1_59.ann         True
# 1             dpej  ejemplo_1_65.ann         True
# 2             dpej  ejemplo_1_71.ann         True
# 3             dpej   ejemplo_1_0.ann         True
# 4             dpej   ejemplo_1_1.ann         True
# ..             ...               ...          ...
# 559  attentionRank  ejemplo_1_68.ann         True
# 560  attentionRank  ejemplo_1_54.ann         True
# 561  attentionRank  ejemplo_1_40.ann         True
# 562  attentionRank  ejemplo_1_97.ann         True
# 563  attentionRank  ejemplo_1_83.ann         True
#
# [564 rows x 3 columns]

# %%
# Comprobamos que funciona con REBEL
labourlaw = df[df['path']=='attentionRank']
display(labourlaw)
# Out:
#               path          ann_file  has_content
# 423  attentionRank  ejemplo_1_59.ann         True
# 424  attentionRank  ejemplo_1_65.ann         True
# 425  attentionRank  ejemplo_1_71.ann         True
# 426  attentionRank   ejemplo_1_0.ann         True
# 427  attentionRank   ejemplo_1_1.ann         True
# ..             ...               ...          ...
# 559  attentionRank  ejemplo_1_68.ann         True
# 560  attentionRank  ejemplo_1_54.ann         True
# 561  attentionRank  ejemplo_1_40.ann         True
# 562  attentionRank  ejemplo_1_97.ann         True
# 563  attentionRank  ejemplo_1_83.ann         True
#
# [141 rows x 3 columns]

# %%
import random

# Filtramos solo las filas donde has_content es True
df_with_content = df[df['has_content'] == True]

# Verificamos si hay archivos .ann comunes entre los distintos paths
common_files = df_with_content['ann_file'].value_counts()
common_files = common_files[common_files == df_with_content['path'].nunique()]

# %%
display(common_files)
# Out:
# ann_file
# ejemplo_1_59.ann     4
# ejemplo_1_126.ann    4
# ejemplo_1_118.ann    4
# ejemplo_1_20.ann     4
# ejemplo_1_34.ann     4
#                     ..
# ejemplo_1_115.ann    4
# ejemplo_1_101.ann    4
# ejemplo_1_11.ann     4
# ejemplo_1_39.ann     4
# ejemplo_1_83.ann     4
# Name: count, Length: 141, dtype: int64

# %%
# Si existen archivos comunes, seleccionamos uno al azar
if not common_files.empty:
    selected_file = random.choice(common_files.index.tolist())
else:
    selected_file = None  # No hay archivos comunes con contenido

print(selected_file)
# Out:
# ejemplo_1_83.ann

# %%
def carga_ann(ann_file):
    annotations = []
    try:
        with open(ann_file, 'r') as file:
            for line in file:
                annotations.append(line.strip())  # Agrega cada línea al array de annotations
    except FileNotFoundError:
        print(f"Archivo {ann_file} no encontrado.")
    return annotations

# %%
capas = df["path"].unique()
print(capas)
# Out:
# ['dpej' 'termcat' 'recursos_mar' 'attentionRank']

# %%
# Diccionario para los sufijos
suffixes = {
    'dpej': "DPEJ",
    'termcat': "Termcat",
    'dictovictor': "DV",
    'attentionRank': "AttentionRank", 
    'labourlaw': "LabourLaw",
    'iate': "IATE" ,
    'recursos_mar':"Tributario"
}
print(suffixes)

# Archivo donde se guardarán todas las anotaciones combinadas
output_path = base+"/estatuto_comun/"
output_file = output_path+selected_file
print(output_file)
# Out:
# {'dpej': 'DPEJ', 'termcat': 'Termcat', 'dictovictor': 'DV', 'attentionRank': 'AttentionRank', 'labourlaw': 'LabourLaw', 'iate': 'IATE', 'recursos_mar': 'Tributario'}
# /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_83.ann

# %%
#---------- PARA UN UNICO ARCHIVO



# terms = []       # Lista para almacenar términos (inicia con 'T')
# relations = []   # Lista para almacenar relaciones (inicia con 'R')

# # Contadores para numerar términos y relaciones de manera única
# term_counter = 1
# relation_counter = 1


# # Crea el archivo de salida

# # Recorre cada item en el diccionario 'general'
# for item in general:
#     path = item['path']
#     ann_files = [file for file in item['archivos'] if file == selected_file]
    
#     # Determina el sufijo para las anotaciones en función del path
#     suffix = suffixes.get(path, "")

#     for ann_file in ann_files:
#         full_path = base+"/"+path+"/"+ann_file
#         annotations = carga_ann(full_path)
        
#          # Modifica y guarda cada línea de anotación según su tipo
#         for annotation in annotations:
#             parts = annotation.split()
#             if annotation.startswith("T"):  # Si es un término
#                 label = parts[1] + f"-{suffix}"  # Añade el sufijo a la etiqueta
#                 modified_annotation = f"T{term_counter} {label} " + " ".join(parts[2:])
#                 terms.append(modified_annotation)
#                 term_counter += 1
#             elif annotation.startswith("R"):  # Si es una relación
#                 label = parts[1] + f"-{suffix}"  # Añade el sufijo a la etiqueta
#                 modified_annotation = f"R{relation_counter} {label} " + " ".join(parts[2:])
#                 relations.append(modified_annotation)
#                 relation_counter += 1
#             else:
#                 # Otras líneas que no comiencen con T o R (si existen) se guardan sin cambios
#                 terms.append(annotation)

# # Escribe todos los términos y luego todas las relaciones en el archivo de salida
# with open(output_file, 'w') as output:
#     for term in terms:
#         output.write(term + '\n')
#     for relation in relations:
#         output.write(relation + '\n')

# print(f"Archivo combinado guardado en {output_file} con numeración correcta y organización de términos y relaciones.")

# %%
# import os

#---------- PROBLEMAS DE TABULACION
# Nota: podria usar directamente df.

# def procesar_anotaciones(general, selected_file, base, suffixes, output_file):
#     """
#     Procesa anotaciones de archivos .ann y las guarda en un archivo de salida,
#     numerando correctamente términos y relaciones.

#     :param general: Lista de diccionarios con información de paths y archivos.
#     :param selected_file: Nombre del archivo .ann a procesar.
#     :param base: Ruta base donde se encuentran los archivos.
#     :param suffixes: Diccionario que asigna sufijos según el path.
#     :param output_file: Nombre del archivo donde se guardará la salida.
#     """
#     terms = []       # Lista para almacenar términos (inicia con 'T')
#     relations = []   # Lista para almacenar relaciones (inicia con 'R')

#     # Contadores para numerar términos y relaciones de manera única
#     term_counter = 1
#     relation_counter = 1

#     # Recorre cada item en el diccionario 'general'
#     for item in general:
#         path = item['path']
#         ann_files = [file for file in item['archivos'] if file == selected_file]
        
#         # Determina el sufijo para las anotaciones en función del path
#         suffix = suffixes.get(path, "")

#         for ann_file in ann_files:
#             full_path = os.path.join(base, path, ann_file)
#             annotations = carga_ann(full_path)  # Función para cargar el contenido del archivo .ann
            
#             # Modifica y guarda cada línea de anotación según su tipo
#             for annotation in annotations:
#                 parts = annotation.split()
#                 if annotation.startswith("T"):  # Si es un término
#                     if parts[1] == "concept":
#                         label = "Term" + f"-{suffix}"  # Añade el sufijo a la etiqueta
#                         modified_annotation = f"T{term_counter} {label} " + " ".join(parts[2:]) #PROBLEMA!!!!!
#                         terms.append(modified_annotation)
#                         term_counter += 1
#                     else:
#                         label = parts[1] + f"-{suffix}"  # Añade el sufijo a la etiqueta
#                         modified_annotation = f"T{term_counter} {label} " + " ".join(parts[2:]) #PROBLEMA!!!!!
#                         terms.append(modified_annotation)
#                         term_counter += 1
#                 elif annotation.startswith("R"):  # Si es una relación
#                     label = parts[1] + f"-{suffix}"  # Añade el sufijo a la etiqueta
#                     modified_annotation = f"R{relation_counter} {label} " + " ".join(parts[2:]) #PROBLEMA!!!!!
#                     relations.append(modified_annotation)
#                     relation_counter += 1
#                 else:
#                     # Otras líneas que no comiencen con T o R (si existen) se guardan sin cambios
#                     terms.append(annotation)

#     # Escribir todos los términos y luego todas las relaciones en el archivo de salida
#     with open(output_file, 'w', encoding='utf-8') as output:
#         for term in terms:
#             output.write(term + '\n')
#         for relation in relations:
#             output.write(relation + '\n')

#     print(f"Archivo combinado guardado en {output_file} con numeración correcta y organización de términos y relaciones.")

# %%
#---------- SOLUCION DE TABULACION Y CAMBIO DE CONCEPT A TERM


# import os

# def procesar_anotaciones(general, selected_file, base, suffixes, output_file):
#     """
#     Procesa anotaciones de archivos .ann y las guarda en un archivo de salida,
#     numerando correctamente términos y relaciones.

#     :param general: Lista de diccionarios con información de paths y archivos.
#     :param selected_file: Nombre del archivo .ann a procesar.
#     :param base: Ruta base donde se encuentran los archivos.
#     :param suffixes: Diccionario que asigna sufijos según el path.
#     :param output_file: Nombre del archivo donde se guardará la salida.
#     """
#     terms = []       # Lista para almacenar términos (inicia con 'T')
#     relations = []   # Lista para almacenar relaciones (inicia con 'R')

#     # Contadores para numerar términos y relaciones de manera única
#     term_counter = 1
#     relation_counter = 1

#     # Recorre cada item en el diccionario 'general'
#     for item in general:
#         path = item['path']
#         ann_files = [file for file in item['archivos'] if file == selected_file]
        
#         # Determina el sufijo para las anotaciones en función del path
#         suffix = suffixes.get(path, "")

#         for ann_file in ann_files:
#             full_path = os.path.join(base, path, ann_file)
#             annotations = carga_ann(full_path)  # Función para cargar el contenido del archivo .ann
            
#             # Modifica y guarda cada línea de anotación según su tipo
#             for annotation in annotations:
#                 parts = annotation.split()
                
#                 # ----- Si es un TÉRMINO (empieza con "T") -----
#                 if annotation.startswith("T"):
#                     # El label depende de si parts[1] == "concept"
#                     if parts[1] == "concept":
#                         label = "Term" + f"-{suffix}"
#                     else:
#                         label = parts[1] + f"-{suffix}"
                    
#                     # Formato BRAT para términos:
#                     # T<ID> <LABEL> <START> <END> <TEXTO>
#                     # parts: [ "TX", "concept", "144", "156", ... texto... ]
#                     start = parts[2]
#                     end = parts[3]
#                     text = " ".join(parts[4:])  # El resto se considera el texto del span
                    
#                     modified_annotation = f"T{term_counter}	{label} {start} {end}	{text}"
#                     terms.append(modified_annotation)
#                     term_counter += 1
                
#                 # ----- Si es una RELACIÓN (empieza con "R") -----
#                 elif annotation.startswith("R"):
#                     # Ejemplo BRAT: R1 <LABEL> Arg1:T2 Arg2:T3 ...
#                     label = parts[1] + f"-{suffix}"
#                     args = " ".join(parts[2:])  # Arg1:T2 Arg2:T3 ...
                    
#                     modified_annotation = f"R{relation_counter}	{label} {args}"
#                     relations.append(modified_annotation)
#                     relation_counter += 1
                
#                 # ----- Otros tipos de líneas (no empiezan con T o R) se copian igual -----
#                 else:
#                     terms.append(annotation)

#     # Escribir todos los términos y luego todas las relaciones en el archivo de salida
#     with open(output_file, 'w', encoding='utf-8') as output:
#         for term in terms:
#             output.write(term + '\n')
#         for relation in relations:
#             output.write(relation + '\n')

#     print(f"Archivo combinado guardado en {output_file} con numeración correcta y organización de términos y relaciones.")

# %%
#---------- AGRUPACION DE LAS ETIQUETAS EN DICCIONARIO Y AUTOMATICO. ELIMINAR DICTOVICTOR


import os

def procesar_anotaciones(general, selected_file, base, suffixes, output_file):
    """
    Procesa anotaciones de archivos .ann y las guarda en un archivo de salida,
    numerando correctamente términos y relaciones.

    :param general: Lista de diccionarios con información de paths y archivos.
    :param selected_file: Nombre del archivo .ann a procesar.
    :param base: Ruta base donde se encuentran los archivos.
    :param suffixes: Diccionario que asigna sufijos según el path.
    :param output_file: Nombre del archivo donde se guardará la salida.
    """
    terms = []       # Lista para almacenar términos (inicia con 'T')
    relations = []   # Lista para almacenar relaciones (inicia con 'R')

    # Contadores para numerar términos y relaciones de manera única
    term_counter = 1
    relation_counter = 1
    note_counter = 1  # Para las líneas # de notas

    # Este diccionario mapeará entity_key -> t_id
    # entity_key podría ser (label, start, end, text) o como prefieras
    annotation_map = {}

    
    # Recorre cada item en el diccionario 'general'
    for item in general:
        path = item['path']
        ann_files = [file for file in item['archivos'] if file == selected_file]
        
        # Determina el sufijo para las anotaciones en función del path
        suffix = suffixes.get(path, "") # Parte derecha del diccio
        # print(f"[DEBUG] suffix='{suffix}'")


        for ann_file in ann_files:
            full_path = os.path.join(base, path, ann_file)
            annotations = carga_ann(full_path)  # Función para cargar el contenido del archivo .ann
            
            # Modifica y guarda cada línea de anotación según su tipo
            for annotation in annotations:
                parts = annotation.split()

                # ----- Si es un TÉRMINO (empieza con "T") -----
                if annotation.startswith("T"):

                    if suffix == "DV": # Eliminamos aqui
                        continue
                    
                    if suffix == "AttentionRank":
                        label_general = "automatico"
                    else:
                        label_general = "refs"
                    
                    # 2) Asignar el label (si parts[1] == "concept")
                    if parts[1] == "concept":
                        label = f"Term-{label_general}"
                    else:
                        label = f"{parts[1]}-{label_general}"
                        
                    # Formato BRAT para términos:
                    # T<ID> <LABEL> <START> <END> <TEXTO>
                    # parts: [ "TX", "concept", "144", "156", ... texto... ]
                    start = parts[2]
                    end = parts[3]
                    text = " ".join(parts[4:])  # El resto se considera el texto del span
                    
                    

                    # 4) Construir una “clave” que identifique la entidad
                    #    para ver si ya existe:
                    entity_key = (label, start, end, text)

                    if entity_key not in annotation_map:
                        # No existe esta entidad -> creamos T<ID>   
                        modified_annotation = f"T{term_counter}	{label} {start} {end}	{text}"


                    # if modified_annotation not in terms:
                        terms.append(modified_annotation)

                        annotation_map[entity_key] = term_counter
                        
                        # ----- Añadir el label dentro de notas -----
                        # Ej: #1	AnnotatorNotes T2 "IATE"
                        note_line = f"#{note_counter}	AnnotatorNotes T{term_counter}	\"{suffix}\""
                        terms.append(note_line)
                        note_counter += 1

                        term_counter += 1
                    else:
                        # Si la entidad ya existe, recuperamos su T<ID>
                        existing_tid = annotation_map[entity_key]

                        # ----- Añadir el label dentro de notas -----
                        # Ej: #1	AnnotatorNotes T2 "IATE"
                        note_line = f"#{note_counter}	AnnotatorNotes T{existing_tid}	\"{suffix}\""
                        terms.append(note_line)
                        note_counter += 1
                
                # ----- Si es una RELACIÓN (empieza con "R") ----- De momento esta parte no se utiliza, pero la podemos trillar como la de arriba
                elif annotation.startswith("R"):
                    # Ejemplo BRAT: R1 <LABEL> Arg1:T2 Arg2:T3 ...
                    label = parts[1] + f"-{suffix}"
                    args = " ".join(parts[2:])  # Arg1:T2 Arg2:T3 ...
                    
                    modified_annotation = f"R{relation_counter}	{label} {args}"
                    relations.append(modified_annotation)
                    relation_counter += 1
                
                # ----- Otros tipos de líneas (no empiezan con T o R) se copian igual -----
                else:
                    terms.append(annotation)

    # Escribir todos los términos y luego todas las relaciones en el archivo de salida
    with open(output_file, 'w', encoding='utf-8') as output:
        for term in terms:
            output.write(term + '\n')
        for relation in relations:
            output.write(relation + '\n')

    print(f"Archivo combinado guardado en {output_file} con numeración correcta y organización de términos y relaciones.")

# %%
procesar_anotaciones(general, selected_file, base, suffixes, output_file)
# Out:
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_83.ann con numeración correcta y organización de términos y relaciones.

# %%
display(df)
# Out:
#               path          ann_file  has_content
# 0             dpej  ejemplo_1_59.ann         True
# 1             dpej  ejemplo_1_65.ann         True
# 2             dpej  ejemplo_1_71.ann         True
# 3             dpej   ejemplo_1_0.ann         True
# 4             dpej   ejemplo_1_1.ann         True
# ..             ...               ...          ...
# 559  attentionRank  ejemplo_1_68.ann         True
# 560  attentionRank  ejemplo_1_54.ann         True
# 561  attentionRank  ejemplo_1_40.ann         True
# 562  attentionRank  ejemplo_1_97.ann         True
# 563  attentionRank  ejemplo_1_83.ann         True
#
# [564 rows x 3 columns]

# %%
def preparar_rutas(df, base_path, output_path):
    """
    Para cada fila del DataFrame, construye dos columnas:
    - 'selected_file': base_path + path + ann_file
    - 'output_file':   output_path + ann_file
    """
    # Crear la columna 'selected_file'
    df["selected_file"] = df.apply(
        lambda row: os.path.join(base_path, row["path"], row["ann_file"]), 
        axis=1
    )

    # Crear la columna 'output_file'
    df["output_file"] = df.apply(
        lambda row: os.path.join(output_path, row["ann_file"]), 
        axis=1
    )

    return df

# %%
df = preparar_rutas(df, base, output_path)
display(df)
# Out:
#               path          ann_file  has_content  \
# 0             dpej  ejemplo_1_59.ann         True
# 1             dpej  ejemplo_1_65.ann         True
# 2             dpej  ejemplo_1_71.ann         True
# 3             dpej   ejemplo_1_0.ann         True
# 4             dpej   ejemplo_1_1.ann         True
# ..             ...               ...          ...
# 559  attentionRank  ejemplo_1_68.ann         True
# 560  attentionRank  ejemplo_1_54.ann         True
# 561  attentionRank  ejemplo_1_40.ann         True
# 562  attentionRank  ejemplo_1_97.ann         True
# 563  attentionRank  ejemplo_1_83.ann         True
#
#                                          selected_file  \
# 0    /Users/jpardo/Desktop/Proyectos/TeresIA/Desarr...
# 1    /Users/jpardo/Desktop/Proyectos/TeresIA/Desarr...
# 2    /Users/jpardo/Desktop/Proyectos/TeresIA/Desarr...
# 3    /Users/jpardo/Desktop/Proyectos/TeresIA/Desarr...
# 4    /Users/jpardo/Desktop/Proyectos/TeresIA/Desarr...
# ..                                                 ...
# 559  /Users/jpardo/Desktop/Proyectos/TeresIA/Desarr...
# 560  /Users/jpardo/Desktop/Proyectos/TeresIA/Desarr...
# 561  /Users/jpardo/Desktop/Proyectos/TeresIA/Desarr...
# 562  /Users/jpardo/Desktop/Proyectos/TeresIA/Desarr...
# 563  /Users/jpardo/Desktop/Proyectos/TeresIA/Desarr...
#
#                                            output_file
# 0    /Users/jpardo/Desktop/Proyectos/TeresIA/Desarr...
# 1    /Users/jpardo/Desktop/Proyectos/TeresIA/Desarr...
# 2    /Users/jpardo/Desktop/Proyectos/TeresIA/Desarr...
# 3    /Users/jpardo/Desktop/Proyectos/TeresIA/Desarr...
# 4    /Users/jpardo/Desktop/Proyectos/TeresIA/Desarr...
# ..                                                 ...
# 559  /Users/jpardo/Desktop/Proyectos/TeresIA/Desarr...
# 560  /Users/jpardo/Desktop/Proyectos/TeresIA/Desarr...
# 561  /Users/jpardo/Desktop/Proyectos/TeresIA/Desarr...
# 562  /Users/jpardo/Desktop/Proyectos/TeresIA/Desarr...
# 563  /Users/jpardo/Desktop/Proyectos/TeresIA/Desarr...
#
# [564 rows x 5 columns]

# %%
for _, row in df.iterrows():
    # Extraer solo el nombre .ann
    ann_file_name = os.path.basename(row["selected_file"])  # "articulo_52_parrafo_6.ann"
    
    # Obtener la carpeta base (si tu 'procesar_anotaciones' la usa)
    # base_folder = os.path.dirname(row["selected_file"])     # "/ruta/base/termcat"

    # Llamar a la función original
    procesar_anotaciones(
        general=general, 
        selected_file=ann_file_name, 
        base=base, 
        suffixes=suffixes, 
        output_file=row["output_file"]
    )
# Out:
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_59.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_65.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_71.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_0.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_1.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_70.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_64.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_58.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_99.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_72.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_66.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_3.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_2.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_67.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_73.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_98.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_88.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_77.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_63.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_6.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_7.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_62.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_76.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_89.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_60.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_74.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_48.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_5.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_4.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_49.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_75.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_61.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_12.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_116.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_102.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_103.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_117.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_13.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_39.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_11.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_101.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_115.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_129.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_128.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_114.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_100.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_10.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_38.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_14.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_28.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_138.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_104.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_110.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_111.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_105.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_139.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_29.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_15.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_17.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_113.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_107.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_106.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_112.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_16.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_27.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_33.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_137.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_123.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_122.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_136.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_32.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_26.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_18.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_30.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_24.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_120.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_134.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_108.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_109.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_135.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_121.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_25.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_31.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_19.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_35.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_21.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_119.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_125.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_131.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_130.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_124.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_118.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_20.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_34.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_22.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_36.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_132.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_126.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_127.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_133.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_37.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_23.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_87.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_93.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_78.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_44.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_50.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_9.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_140.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_8.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_51.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_45.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_79.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_92.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_86.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_90.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_84.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_53.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_47.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_46.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_52.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_85.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_91.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_95.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_81.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_56.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_42.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_43.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_57.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_80.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_94.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_82.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_96.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_41.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_55.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_69.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_68.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_54.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_40.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_97.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_83.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_59.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_65.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_71.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_0.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_1.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_70.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_64.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_58.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_99.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_72.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_66.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_3.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_2.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_67.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_73.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_98.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_88.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_77.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_63.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_6.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_7.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_62.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_76.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_89.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_60.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_74.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_48.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_5.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_4.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_49.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_75.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_61.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_12.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_116.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_102.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_103.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_117.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_13.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_39.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_11.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_101.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_115.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_129.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_128.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_114.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_100.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_10.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_38.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_14.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_28.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_138.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_104.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_110.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_111.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_105.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_139.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_29.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_15.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_17.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_113.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_107.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_106.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_112.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_16.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_27.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_33.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_137.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_123.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_122.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_136.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_32.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_26.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_18.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_30.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_24.ann con numeración correcta y organización de términos y relaciones.
# ...
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_136.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_32.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_26.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_18.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_30.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_24.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_120.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_134.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_108.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_109.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_135.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_121.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_25.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_31.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_19.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_35.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_21.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_119.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_125.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_131.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_130.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_124.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_118.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_20.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_34.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_22.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_36.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_132.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_126.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_127.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_133.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_37.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_23.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_87.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_93.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_78.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_44.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_50.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_9.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_140.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_8.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_51.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_45.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_79.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_92.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_86.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_90.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_84.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_53.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_47.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_46.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_52.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_85.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_91.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_95.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_81.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_56.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_42.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_43.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_57.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_80.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_94.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_82.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_96.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_41.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_55.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_69.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_68.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_54.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_40.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_97.ann con numeración correcta y organización de términos y relaciones.
# Archivo combinado guardado en /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/tributario/anotacion/estatuto_comun/ejemplo_1_83.ann con numeración correcta y organización de términos y relaciones.

# %% [markdown]
# # CONF

# %% [markdown]
# ## annotation

# %%
import os

def merge_annotation_conf(files, output_file):
    """
    Combina varios archivos de configuración (annotation.conf) en uno solo.

    :param files: Lista con las rutas de los archivos .conf que quieres fusionar.
    :param output_file: Nombre del archivo de salida (por ejemplo: 'annotation.conf').
    """
    # Estructuras para almacenar datos de cada sección
    sections = {
        "entities": set(),
        "attributes": set(),
        "relations": set(),
        "events": set(),

        # Agrega más secciones si las necesitas,
        # por ejemplo: "attributes", "equivs", etc.
    }

    # Sección actual durante la lectura
    current_section = None

    for conf_file in files:
        if not os.path.exists(conf_file):
            print(f"El archivo {conf_file} no existe. Se omite.")
            continue

        with open(conf_file, "r", encoding="utf-8") as f:
            for line in f:
                line = line.strip()
                if not line:
                    continue  # Saltar líneas vacías

                # Detectar sección
                if line.startswith("[") and line.endswith("]"):
                    # Quitar corchetes para obtener el nombre
                    section_name = line[1:-1].lower()
                    # Actualizar sección actual si está en el diccionario
                    if section_name in sections.keys():
                        current_section = section_name
                    else:
                        # Si encuentras secciones no reconocidas, podrías
                        # crear una nueva entrada en `sections` o ignorarla
                        current_section = None
                else:
                    # Si estamos en una sección conocida, añadir la línea
                    if current_section in sections:
                        sections[current_section].add(line)

    # Crear o sobrescribir el archivo de salida
    with open(output_file, "w", encoding="utf-8") as out:
        # Recorrer cada sección en orden
        for section_name, items in sections.items():
            # Escribir cabecera de sección
            out.write(f"[{section_name}]\n")
            # Ordenar items para que sea reproducible
            for item in sorted(items):
                out.write(item + "\n")
            out.write("\n")  # Salto de línea tras cada sección

    print(f"Se han combinado los archivos en '{output_file}'.")

# %%
files_to_merge = []
for i in capas:
    conf1 = base+"/"+i+"/annotation.conf"
    print(conf1)
    files_to_merge.append(conf1)
# Out:
# /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/estatuto_laboral/dpej/annotation.conf
# /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/estatuto_laboral/termcat/annotation.conf
# /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/estatuto_laboral/dictovictor/annotation.conf
# /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/estatuto_laboral/attentionRank/annotation.conf
# /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/estatuto_laboral/labourlaw/annotation.conf
# /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/estatuto_laboral/iate/annotation.conf

# %%
conf1_path = output_path+"/annotation.conf"
merge_annotation_conf(files_to_merge, conf1_path)
# Out:
# Se han combinado los archivos en '/Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/estatuto_laboral/estatuto_comun//annotation.conf'.

# %%
import os

def actualizar_annotation_conf(ann_file, annotation_conf_file):
    """
    Actualiza el archivo annotation_conf_file agregando etiquetas
    (entities y relations) encontradas en ann_file.

    :param ann_file: Ruta a un archivo .ann que contiene anotaciones combinadas.
    :param annotation_conf_file: Ruta al archivo annotation.conf ya fusionado
                                 que queremos actualizar con nuevas etiquetas.
    """
    # 1) Extraer nuevas entidades y relaciones del .ann
    new_entities = set()
    new_relations = set()

    if not os.path.exists(ann_file):
        print(f"El archivo .ann '{ann_file}' no existe. Se omite actualización.")
        return

    with open(ann_file, 'r', encoding='utf-8') as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            
            # T<id> <label> <start> <end> <texto>
            if line.startswith("T"):
                parts = line.split()
                if len(parts) > 1:
                    label = parts[1]
                    new_entities.add(label)

            # R<id> <label> Arg1:T# Arg2:T# ...
            elif line.startswith("R"):
                parts = line.split()
                if len(parts) > 1:
                    label = parts[1]
                    new_relations.add(label)

    # Si no hay nada nuevo, podemos opcionalmente abortar
    if not new_entities and not new_relations:
        print("No se encontraron nuevas entidades o relaciones en el archivo .ann.")
        return

    # 2) Leer y parsear el annotation.conf final (ya fusionado)
    sections = {
        "entities": set(),
        "attributes": set(),
        "relations": set(),
        "events": set(),
    }
    current_section = None

    if not os.path.exists(annotation_conf_file):
        print(f"El archivo de configuración '{annotation_conf_file}' no existe.")
        return

    with open(annotation_conf_file, "r", encoding="utf-8") as cf:
        for line in cf:
            line_stripped = line.strip()
            if not line_stripped:
                continue

            # Detectar [secciones]
            if line_stripped.startswith("[") and line_stripped.endswith("]"):
                sec_name = line_stripped[1:-1].lower()  # "entities", "relations", etc.
                if sec_name in sections:
                    current_section = sec_name
                else:
                    current_section = None
            else:
                # Guardar la línea en la sección actual (si es válida)
                if current_section in sections:
                    sections[current_section].add(line_stripped)

    # 3) Actualizar secciones con las nuevas etiquetas
    #    (suponemos que todas las etiquetas "T" van a entities y "R" van a relations)
    sections["entities"].update(new_entities)
    sections["relations"].update(new_relations)

    # 4) Reescribir el annotation.conf actualizado
    with open(annotation_conf_file, "w", encoding="utf-8") as out:
        for sec, items in sections.items():
            out.write(f"[{sec}]\n")
            for item in sorted(items):
                out.write(item + "\n")
            out.write("\n")

    print(f"Archivo '{annotation_conf_file}' actualizado con nuevas etiquetas de '{ann_file}'.")

# %%
# Actualizar annotation.conf final con las nuevas etiquetas detectadas en el .ann:
actualizar_annotation_conf("/Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/estatuto_laboral/estatuto_comun/articulo_1_parrafo_1.ann", conf1_path)
# Out:
# Archivo '/Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/estatuto_laboral/estatuto_comun//annotation.conf' actualizado con nuevas etiquetas de '/Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/estatuto_laboral/estatuto_comun/articulo_1_parrafo_1.ann'.

# %% [markdown]
# ## tools

# %%
import os

import os

def merge_tools_conf(files, output_file):
    """
    Combina varios archivos tools.conf en uno solo,
    unificando solo la sección [options] sin duplicados.
    
    :param files: Lista de rutas de archivos .conf que quieres fusionar.
    :param output_file: Nombre (o ruta) del archivo de salida resultante, ej. 'tools.conf'.
    """
    # Usamos un set para no duplicar opciones
    options_set = set()

    current_section = None

    for conf_file in files:
        if not os.path.exists(conf_file):
            print(f"El archivo {conf_file} no existe. Se omite.")
            continue

        with open(conf_file, "r", encoding="utf-8") as f:
            for line in f:
                line = line.strip()

                # Saltar líneas vacías
                if not line:
                    continue

                # Detectar si empieza sección [options]
                if line.startswith("[") and line.endswith("]"):
                    section_name = line[1:-1].lower()
                    # Si encontramos [options], cambiamos current_section
                    if section_name == "options":
                        current_section = "options"
                    else:
                        current_section = None
                else:
                    # Si estamos en la sección [options], añadimos la línea al set
                    if current_section == "options":
                        options_set.add(line)

    # Escribir archivo final con la sección [options]
    with open(output_file, "w", encoding="utf-8") as out:
        out.write("[options]\n")
        # Ordenar las líneas para tener consistencia
        for item in sorted(options_set):
            out.write(item + "\n")

    print(f"Se han combinado los archivos en '{output_file}'.")

# %%
files_to_merge = []
for i in capas:
    conf3 = base+"/"+i+"/tools.conf"
    print(conf3)
    files_to_merge.append(conf3)
# Out:
# /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/estatuto_laboral/dpej/tools.conf
# /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/estatuto_laboral/termcat/tools.conf
# /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/estatuto_laboral/dictovictor/tools.conf
# /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/estatuto_laboral/attentionRank/tools.conf
# /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/estatuto_laboral/labourlaw/tools.conf
# /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/estatuto_laboral/iate/tools.conf

# %%
conf2_path = output_path+"/tools.conf"
merge_tools_conf(files_to_merge, conf2_path)
# Out:
# Se han combinado los archivos en '/Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/estatuto_laboral/estatuto_comun//tools.conf'.

# %% [markdown]
# ## visual

# %%
import os

def merge_visual_conf(files, output_file):
    """
    Combina varios archivos visual.conf en uno solo,
    unificando sus secciones [labels] y [drawing] sin duplicados.
    
    :param files: Lista de rutas de archivos .conf que quieres fusionar.
    :param output_file: Nombre (o ruta) del archivo de salida resultante, ej. 'visual.conf'.
    """
    # Diccionario para almacenar cada sección en un set (evitar duplicados)
    sections = {
        "labels": set(),
        "drawing": set()
    }

    current_section = None

    for conf_file in files:
        if not os.path.exists(conf_file):
            print(f"El archivo {conf_file} no existe. Se omite.")
            continue

        with open(conf_file, "r", encoding="utf-8") as f:
            for line in f:
                line = line.strip()
                # Omitir líneas vacías
                if not line:
                    continue

                # Detectar cabecera de sección, p.ej. "[labels]", "[drawing]"
                if line.startswith("[") and line.endswith("]"):
                    section_name = line[1:-1].lower()  # convertir a minúsculas
                    if section_name in sections:
                        current_section = section_name
                    else:
                        current_section = None
                else:
                    # Si estamos dentro de una sección válida, agregamos la línea
                    if current_section in sections:
                        sections[current_section].add(line)

    # Crear o sobrescribir el archivo de salida con las secciones unificadas
    with open(output_file, "w", encoding="utf-8") as out:
        # Sección [labels]
        out.write("[labels]\n")
        for item in sorted(sections["labels"]):
            out.write(item + "\n")
        out.write("\n")

        # Sección [drawing]
        out.write("[drawing]\n")
        for item in sorted(sections["drawing"]):
            out.write(item + "\n")
        out.write("\n")

    print(f"Se han combinado los archivos en '{output_file}'.")

# %%
files_to_merge = []
for i in capas:
    conf3 = base+"/"+i+"/visual.conf"
    print(conf3)
    files_to_merge.append(conf3)
# Out:
# /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/estatuto_laboral/dpej/visual.conf
# /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/estatuto_laboral/termcat/visual.conf
# /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/estatuto_laboral/dictovictor/visual.conf
# /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/estatuto_laboral/attentionRank/visual.conf
# /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/estatuto_laboral/labourlaw/visual.conf
# /Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/estatuto_laboral/iate/visual.conf

# %%
conf3_path = output_path+"/visual.conf"
merge_visual_conf(files_to_merge, conf3_path)
# Out:
# Se han combinado los archivos en '/Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/estatuto_laboral/estatuto_comun//visual.conf'.

# %%
import os
import random

def actualizar_visual_conf(ann_file, visual_conf_file):
    """
    Actualiza el archivo 'visual_conf_file' agregando las etiquetas
    encontradas en 'ann_file' (líneas que inicien con T) y asignando
    un color distinto a cada una en la sección [drawing].

    :param ann_file: Ruta al archivo .ann combinado (que contiene nuevas etiquetas).
    :param visual_conf_file: Ruta al archivo 'visual.conf' ya fusionado que se modificará.
    """
    # 1) Extraer las nuevas etiquetas del archivo .ann
    new_labels = set()
    if not os.path.exists(ann_file):
        print(f"El archivo .ann '{ann_file}' no existe. Se omite la actualización.")
        return

    with open(ann_file, 'r', encoding='utf-8') as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            # Cada línea de término: T<num> <etiqueta> <start> <end> <texto...>
            if line.startswith("T"):
                parts = line.split()
                if len(parts) > 1:
                    label = parts[1]  # La segunda palabra es la etiqueta
                    new_labels.add(label)

    if not new_labels:
        print("No se encontraron etiquetas nuevas en el archivo .ann.")
        return

    # 2) Leer y parsear el visual.conf final
    sections = {
        "labels": set(),
        "drawing": set()
    }
    current_section = None

    if not os.path.exists(visual_conf_file):
        print(f"El archivo de configuración '{visual_conf_file}' no existe.")
        return

    with open(visual_conf_file, "r", encoding="utf-8") as cf:
        for line in cf:
            line_stripped = line.strip()
            if not line_stripped:
                continue

            # Detectar [labels] o [drawing]
            if line_stripped.startswith("[") and line_stripped.endswith("]"):
                sec_name = line_stripped[1:-1].lower()  # "labels" o "drawing"
                if sec_name in sections:
                    current_section = sec_name
                else:
                    current_section = None
            else:
                if current_section in sections:
                    sections[current_section].add(line_stripped)

    # 3) Generar un color aleatorio para cada etiqueta, y actualizar las secciones
    #    Mantenemos un diccionario de label->color para ser consistente si la etiqueta aparece varias veces
    color_map = {}
    for label in new_labels:
        # Creamos una entrada en [labels]
        # Ejemplo: "concept | CONCEPT"
        sections["labels"].add(f"{label} | {label.upper()}")

        # Generar color si no existe en el map
        if label not in color_map:
            color_map[label] = "#{:06x}".format(random.randint(0, 0xFFFFFF))

        # Creamos una entrada en [drawing]
        # Ejemplo: "concept	bgColor:#ffccaa, fgColor:black, borderColor:darken"
        color_line = f"{label}\tbgColor:{color_map[label]}, fgColor:black, borderColor:darken"
        sections["drawing"].add(color_line)

    # 4) Reescribir el visual.conf actualizado
    with open(visual_conf_file, "w", encoding="utf-8") as out:
        # Sección [labels]
        out.write("[labels]\n")
        for item in sorted(sections["labels"]):
            out.write(item + "\n")
        out.write("\n")

        # Sección [drawing]
        out.write("[drawing]\n")
        for item in sorted(sections["drawing"]):
            out.write(item + "\n")
        out.write("\n")

    print(f"Archivo '{visual_conf_file}' actualizado con las nuevas etiquetas de '{ann_file}'.")

# %%
# Actualizar annotation.conf final con las nuevas etiquetas detectadas en el .ann:
actualizar_visual_conf("/Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/estatuto_laboral/estatuto_comun/articulo_1_parrafo_1.ann", conf3_path)
# Out:
# Archivo '/Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/estatuto_laboral/estatuto_comun//visual.conf' actualizado con las nuevas etiquetas de '/Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/estatuto_laboral/estatuto_comun/articulo_1_parrafo_1.ann'.

# %% [markdown]
# # Renombrar

# %%
import pandas as pd

path = "/Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/corpus/anotacion/parsing.csv"
parsing = pd.read_csv(path)

display(parsing)
# Out:
#                                         old               new        folder
# 0            requerimiento-10_parrafo_1.txt   ejemplo_0_0.txt  artText_UNED
# 1     resolucion-particular-9_parrafo_2.txt   ejemplo_0_1.txt  artText_UNED
# 2     resolucion-particular-9_parrafo_3.txt   ejemplo_0_2.txt  artText_UNED
# 3            requerimiento-14_parrafo_1.txt   ejemplo_0_3.txt  artText_UNED
# 4           acta-inspeccion-8_parrafo_1.txt   ejemplo_0_4.txt  artText_UNED
# ...                                     ...               ...           ...
# 2823            d00026-plain_parrafo_20.txt  ejemplo_7_39.txt    Admin_IULA
# 2824            d00026-plain_parrafo_36.txt  ejemplo_7_40.txt    Admin_IULA
# 2825            d00026-plain_parrafo_22.txt  ejemplo_7_41.txt    Admin_IULA
# 2826            d00026-plain_parrafo_23.txt  ejemplo_7_42.txt    Admin_IULA
# 2827            d00026-plain_parrafo_37.txt  ejemplo_7_43.txt    Admin_IULA
#
# [2828 rows x 3 columns]

# %%
laboral2 = parsing[parsing['folder'] == "Laboral2_UPM"]
display(laboral2)
# Out:
#                            old                new        folder
# 285  articulo_45_parrafo_1.txt    ejemplo_3_0.txt  Laboral2_UPM
# 286            articulo_71.txt    ejemplo_3_1.txt  Laboral2_UPM
# 287  articulo_52_parrafo_1.txt    ejemplo_3_2.txt  Laboral2_UPM
# 288            articulo_59.txt    ejemplo_3_3.txt  Laboral2_UPM
# 289  articulo_42_parrafo_5.txt    ejemplo_3_4.txt  Laboral2_UPM
# ..                         ...                ...           ...
# 489            articulo_83.txt  ejemplo_3_204.txt  Laboral2_UPM
# 490  articulo_34_parrafo_1.txt  ejemplo_3_205.txt  Laboral2_UPM
# 491        intro_parrafo_1.txt  ejemplo_3_206.txt  Laboral2_UPM
# 492  articulo_23_parrafo_1.txt  ejemplo_3_207.txt  Laboral2_UPM
# 493  articulo_37_parrafo_4.txt  ejemplo_3_208.txt  Laboral2_UPM
#
# [209 rows x 3 columns]

# %%
import re
import os
import shutil
import chardet
import unicodedata
import pandas as pd


def change_extension(nombre_archivo):
    """
    Cambia la extensión de un nombre de archivo a anotacion.

    :param nombre_archivo: Nombre del archivo con extensión (ej: 'documento.txt')
    :return: Nombre del archivo sin extensión (ej: 'documento')
    """
    name = os.path.splitext(nombre_archivo)[0]
    annot = name+".ann"
    return annot

def remove_accents_and_spaces(text):
    """Elimina tildes y caracteres especiales, y reemplaza espacios con _"""
    # Elimina tildes y caracteres diacríticos
    text = ''.join(c for c in unicodedata.normalize('NFKD', text) if not unicodedata.combining(c))
    # Reemplaza espacios por _
    text = text.replace(" ", "_")
    return text


def rename_files_in_folder(folder_path, dataset): # Modificada y diferente de 'seleccion.ipynb'
    """
    Recorre los archivos de una carpeta y renombra cada archivo según los nombres
    antiguos y nuevos especificados en el DataFrame 'dataset'. Se verifica que cada
    archivo (old) exista en la carpeta y es renombrado al nombre nuevo (new).

    :param folder_path: Ruta de la carpeta que contiene los archivos.
    :param dataset: DataFrame que contiene las columnas 'old' y 'new' con los nombres de archivo.
    :return: DataFrame con los registros de los archivos renombrados (old y new).
    """
    # Lista de archivos actualmente en la carpeta (solo nombres)
    archivos_old = os.listdir(folder_path)
    registros = []  # Para guardar los cambios realizados

    # Iterar sobre cada fila del dataset
    for _, row in dataset.iterrows():
        old_file = row['old']
        new_file = row['new']
        
        # Verificar si el nombre de archivo antiguo existe en la carpeta
        if old_file in archivos_old:
            # Construir la ruta completa del archivo antiguo
            old_path = os.path.join(folder_path, old_file)
            if os.path.isfile(old_path):
                # Construir la ruta completa del nuevo nombre
                new_path = os.path.join(folder_path, new_file)
                # Renombrar el archivo
                os.rename(old_path, new_path)
                print(f"Renamed: {old_file} -> {new_file}")
                registros.append({'old': old_file, 'new': new_file})
            else:
                print(f"Not a file: {old_path}")
        else:
            print(f"File not found: {old_file}")
    
    # Crear un DataFrame con los registros de los archivos renombrados
    df_registros = pd.DataFrame(registros)
    return df_registros

# %%
# Ahora, aplicamos change_extension a las columnas 'old' y 'new'
laboral2['old'] = laboral2['old'].apply(change_extension)
laboral2['new'] = laboral2['new'].apply(change_extension)

# Mostramos el DataFrame resultante
display(laboral2)
# Out:
# /var/folders/wy/5tnvpqhs3tn3h3821ywg2j7w0000gn/T/ipykernel_12331/1158868910.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laboral2['old'] = laboral2['old'].apply(change_extension)
# /var/folders/wy/5tnvpqhs3tn3h3821ywg2j7w0000gn/T/ipykernel_12331/1158868910.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laboral2['new'] = laboral2['new'].apply(change_extension)
#                            old                new        folder
# 285  articulo_45_parrafo_1.ann    ejemplo_3_0.ann  Laboral2_UPM
# 286            articulo_71.ann    ejemplo_3_1.ann  Laboral2_UPM
# 287  articulo_52_parrafo_1.ann    ejemplo_3_2.ann  Laboral2_UPM
# 288            articulo_59.ann    ejemplo_3_3.ann  Laboral2_UPM
# 289  articulo_42_parrafo_5.ann    ejemplo_3_4.ann  Laboral2_UPM
# ..                         ...                ...           ...
# 489            articulo_83.ann  ejemplo_3_204.ann  Laboral2_UPM
# 490  articulo_34_parrafo_1.ann  ejemplo_3_205.ann  Laboral2_UPM
# 491        intro_parrafo_1.ann  ejemplo_3_206.ann  Laboral2_UPM
# 492  articulo_23_parrafo_1.ann  ejemplo_3_207.ann  Laboral2_UPM
# 493  articulo_37_parrafo_4.ann  ejemplo_3_208.ann  Laboral2_UPM
#
# [209 rows x 3 columns]

# %%
# Supongamos que ya tienes un DataFrame, por ejemplo:
df_renamed = rename_files_in_folder("/Users/jpardo/Desktop/Proyectos/TeresIA/Desarrollo/server/gold_standard2/estatuto_laboral/estatuto_comun_renamed", laboral2)
# Out:
# Renamed: articulo_45_parrafo_1.ann -> ejemplo_3_0.ann
# Renamed: articulo_71.ann -> ejemplo_3_1.ann
# Renamed: articulo_52_parrafo_1.ann -> ejemplo_3_2.ann
# Renamed: articulo_59.ann -> ejemplo_3_3.ann
# Renamed: articulo_42_parrafo_5.ann -> ejemplo_3_4.ann
# Renamed: articulo_42_parrafo_4.ann -> ejemplo_3_5.ann
# Renamed: articulo_56_parrafo_1.ann -> ejemplo_3_6.ann
# Renamed: articulo_58.ann -> ejemplo_3_7.ann
# Renamed: articulo_70.ann -> ejemplo_3_8.ann
# Renamed: articulo_64.ann -> ejemplo_3_9.ann
# Renamed: articulo_37_parrafo_8.ann -> ejemplo_3_10.ann
# Renamed: articulo_4_parrafo_1.ann -> ejemplo_3_11.ann
# Renamed: articulo_45_parrafo_2.ann -> ejemplo_3_12.ann
# Renamed: articulo_35_parrafo_1.ann -> ejemplo_3_13.ann
# Renamed: articulo_52_parrafo_2.ann -> ejemplo_3_14.ann
# Renamed: articulo_88_parrafo_1.ann -> ejemplo_3_15.ann
# Renamed: articulo_3.ann -> ejemplo_3_16.ann
# Renamed: articulo_48_parrafo_10.ann -> ejemplo_3_17.ann
# Renamed: articulo_48_parrafo_11.ann -> ejemplo_3_18.ann
# Renamed: articulo_2.ann -> ejemplo_3_19.ann
# Renamed: articulo_56_parrafo_2.ann -> ejemplo_3_20.ann
# Renamed: articulo_26_parrafo_1.ann -> ejemplo_3_21.ann
# Renamed: articulo_67.ann -> ejemplo_3_22.ann
# Renamed: articulo_52_parrafo_3.ann -> ejemplo_3_23.ann
# Renamed: articulo_73.ann -> ejemplo_3_24.ann
# Renamed: articulo_36_parrafo_1.ann -> ejemplo_3_25.ann
# Renamed: articulo_21_parrafo_1.ann -> ejemplo_3_26.ann
# Renamed: articulo_52_parrafo_7.ann -> ejemplo_3_27.ann
# Renamed: articulo_63.ann -> ejemplo_3_28.ann
# Renamed: articulo_68_parrafo_2.ann -> ejemplo_3_29.ann
# Renamed: articulo_42_parrafo_3.ann -> ejemplo_3_30.ann
# Renamed: articulo_6.ann -> ejemplo_3_31.ann
# Renamed: articulo_7.ann -> ejemplo_3_32.ann
# Renamed: articulo_42_parrafo_2.ann -> ejemplo_3_33.ann
# Renamed: articulo_32_parrafo_1.ann -> ejemplo_3_34.ann
# Renamed: articulo_68_parrafo_3.ann -> ejemplo_3_35.ann
# Renamed: intro.ann -> ejemplo_3_36.ann
# Renamed: articulo_62.ann -> ejemplo_3_37.ann
# Renamed: articulo_52_parrafo_6.ann -> ejemplo_3_38.ann
# Renamed: articulo_36_parrafo_2.ann -> ejemplo_3_39.ann
# Renamed: articulo_60.ann -> ejemplo_3_40.ann
# Renamed: articulo_74.ann -> ejemplo_3_41.ann
# Renamed: articulo_52_parrafo_4.ann -> ejemplo_3_42.ann
# Renamed: articulo_68_parrafo_1.ann -> ejemplo_3_43.ann
# Renamed: articulo_5.ann -> ejemplo_3_44.ann
# Renamed: articulo_42_parrafo_1.ann -> ejemplo_3_45.ann
# Renamed: articulo_52_parrafo_5.ann -> ejemplo_3_46.ann
# Renamed: articulo_61.ann -> ejemplo_3_47.ann
# Renamed: articulo_11_parrafo_6.ann -> ejemplo_3_48.ann
# Renamed: articulo_48_parrafo_1.ann -> ejemplo_3_49.ann
# Renamed: articulo_12_parrafo_3.ann -> ejemplo_3_50.ann
# Renamed: articulo_94_parrafo_8.ann -> ejemplo_3_51.ann
# Renamed: articulo_66_parrafo_1.ann -> ejemplo_3_52.ann
# Renamed: articulo_94_parrafo_26.ann -> ejemplo_3_53.ann
# Renamed: articulo_65_parrafo_4.ann -> ejemplo_3_54.ann
# Renamed: articulo_16_parrafo_2.ann -> ejemplo_3_55.ann
# Renamed: articulo_65_parrafo_5.ann -> ejemplo_3_56.ann
# Renamed: articulo_94_parrafo_27.ann -> ejemplo_3_57.ann
# Renamed: articulo_94_parrafo_9.ann -> ejemplo_3_58.ann
# Renamed: articulo_75_parrafo_1.ann -> ejemplo_3_59.ann
# Renamed: articulo_12_parrafo_2.ann -> ejemplo_3_60.ann
# Renamed: articulo_13.ann -> ejemplo_3_61.ann
# Renamed: articulo_11_parrafo_7.ann -> ejemplo_3_62.ann
# Renamed: articulo_11_parrafo_5.ann -> ejemplo_3_63.ann
# Renamed: articulo_38_parrafo_1.ann -> ejemplo_3_64.ann
# Renamed: articulo_48_parrafo_2.ann -> ejemplo_3_65.ann
# Renamed: articulo_92_parrafo_1.ann -> ejemplo_3_66.ann
# Renamed: articulo_94_parrafo_19.ann -> ejemplo_3_67.ann
# Renamed: articulo_94_parrafo_25.ann -> ejemplo_3_68.ann
# Renamed: articulo_15_parrafo_4.ann -> ejemplo_3_69.ann
# Renamed: articulo_94_parrafo_31.ann -> ejemplo_3_70.ann
# Renamed: articulo_16_parrafo_1.ann -> ejemplo_3_71.ann
# Renamed: articulo_15_parrafo_5.ann -> ejemplo_3_72.ann
# Renamed: articulo_94_parrafo_30.ann -> ejemplo_3_73.ann
# Renamed: articulo_94_parrafo_24.ann -> ejemplo_3_74.ann
# Renamed: articulo_94_parrafo_18.ann -> ejemplo_3_75.ann
# Renamed: articulo_12_parrafo_1.ann -> ejemplo_3_76.ann
# Renamed: articulo_48_parrafo_3.ann -> ejemplo_3_77.ann
# Renamed: articulo_10.ann -> ejemplo_3_78.ann
# Renamed: articulo_11_parrafo_4.ann -> ejemplo_3_79.ann
# Renamed: articulo_91_parrafo_1.ann -> ejemplo_3_80.ann
# Renamed: articulo_12_parrafo_5.ann -> ejemplo_3_81.ann
# Renamed: articulo_48_parrafo_7.ann -> ejemplo_3_82.ann
# Renamed: articulo_86_parrafo_1.ann -> ejemplo_3_83.ann
# Renamed: articulo_94_parrafo_20.ann -> ejemplo_3_84.ann
# Renamed: articulo_15_parrafo_1.ann -> ejemplo_3_85.ann
# Renamed: articulo_65_parrafo_2.ann -> ejemplo_3_86.ann
# Renamed: articulo_65_parrafo_3.ann -> ejemplo_3_87.ann
# Renamed: articulo_28_parrafo_1.ann -> ejemplo_3_88.ann
# Renamed: articulo_94_parrafo_21.ann -> ejemplo_3_89.ann
# Renamed: articulo_48_parrafo_6.ann -> ejemplo_3_90.ann
# Renamed: articulo_12_parrafo_4.ann -> ejemplo_3_91.ann
# Renamed: articulo_11_parrafo_1.ann -> ejemplo_3_92.ann
# Renamed: articulo_76_parrafo_2.ann -> ejemplo_3_93.ann
# Renamed: articulo_11_parrafo_3.ann -> ejemplo_3_94.ann
# Renamed: articulo_12_parrafo_6.ann -> ejemplo_3_95.ann
# Renamed: articulo_48_parrafo_4.ann -> ejemplo_3_96.ann
# Renamed: articulo_72_parrafo_1.ann -> ejemplo_3_97.ann
# Renamed: articulo_15_parrafo_2.ann -> ejemplo_3_98.ann
# Renamed: articulo_94_parrafo_23.ann -> ejemplo_3_99.ann
# Renamed: articulo_65_parrafo_1.ann -> ejemplo_3_100.ann
# Renamed: articulo_94_parrafo_22.ann -> ejemplo_3_101.ann
# Renamed: articulo_15_parrafo_3.ann -> ejemplo_3_102.ann
# Renamed: articulo_48_parrafo_5.ann -> ejemplo_3_103.ann
# Renamed: articulo_12_parrafo_7.ann -> ejemplo_3_104.ann
# Renamed: articulo_11_parrafo_2.ann -> ejemplo_3_105.ann
# Renamed: articulo_76_parrafo_1.ann -> ejemplo_3_106.ann
# Renamed: articulo_77_parrafo_2.ann -> ejemplo_3_107.ann
# Renamed: articulo_27.ann -> ejemplo_3_108.ann
# Renamed: articulo_48_parrafo_8.ann -> ejemplo_3_109.ann
# Renamed: articulo_94_parrafo_1.ann -> ejemplo_3_110.ann
# Renamed: articulo_29_parrafo_1.ann -> ejemplo_3_111.ann
# Renamed: articulo_94_parrafo_13.ann -> ejemplo_3_112.ann
# Renamed: articulo_94_parrafo_12.ann -> ejemplo_3_113.ann
# Renamed: articulo_14_parrafo_1.ann -> ejemplo_3_114.ann
# Renamed: articulo_87_parrafo_1.ann -> ejemplo_3_115.ann
# Renamed: articulo_48_parrafo_9.ann -> ejemplo_3_116.ann
# Renamed: articulo_77_parrafo_3.ann -> ejemplo_3_117.ann
# Renamed: articulo_90_parrafo_1.ann -> ejemplo_3_118.ann
# Renamed: articulo_77_parrafo_1.ann -> ejemplo_3_119.ann
# Renamed: articulo_30.ann -> ejemplo_3_120.ann
# Renamed: articulo_24.ann -> ejemplo_3_121.ann
# Renamed: articulo_18.ann -> ejemplo_3_122.ann
# Renamed: articulo_49_parrafo_5.ann -> ejemplo_3_123.ann
# Renamed: articulo_94_parrafo_2.ann -> ejemplo_3_124.ann
# Renamed: articulo_94_parrafo_10.ann -> ejemplo_3_125.ann
# Renamed: articulo_94_parrafo_11.ann -> ejemplo_3_126.ann
# Renamed: articulo_94_parrafo_3.ann -> ejemplo_3_127.ann
# Renamed: articulo_87_parrafo_2.ann -> ejemplo_3_128.ann
# Renamed: articulo_49_parrafo_4.ann -> ejemplo_3_129.ann
# Renamed: articulo_25.ann -> ejemplo_3_130.ann
# Renamed: articulo_31.ann -> ejemplo_3_131.ann
# Renamed: articulo_94_parrafo_7.ann -> ejemplo_3_132.ann
# Renamed: articulo_94_parrafo_15.ann -> ejemplo_3_133.ann
# Renamed: articulo_94_parrafo_29.ann -> ejemplo_3_134.ann
# Renamed: articulo_94_parrafo_28.ann -> ejemplo_3_135.ann
# Renamed: articulo_94_parrafo_14.ann -> ejemplo_3_136.ann
# Renamed: articulo_94_parrafo_6.ann -> ejemplo_3_137.ann
# Renamed: articulo_49_parrafo_1.ann -> ejemplo_3_138.ann
# Renamed: articulo_8_parrafo_2.ann -> ejemplo_3_139.ann
# Renamed: articulo_11_parrafo_8.ann -> ejemplo_3_140.ann
# Renamed: articulo_84_parrafo_2.ann -> ejemplo_3_141.ann
# Renamed: articulo_22.ann -> ejemplo_3_142.ann
# Renamed: articulo_49_parrafo_3.ann -> ejemplo_3_143.ann
# Renamed: articulo_94_parrafo_4.ann -> ejemplo_3_144.ann
# Renamed: articulo_94_parrafo_16.ann -> ejemplo_3_145.ann
# Renamed: articulo_17_parrafo_1.ann -> ejemplo_3_146.ann
# Renamed: articulo_94_parrafo_17.ann -> ejemplo_3_147.ann
# Renamed: articulo_94_parrafo_5.ann -> ejemplo_3_148.ann
# Renamed: articulo_93_parrafo_1.ann -> ejemplo_3_149.ann
# Renamed: articulo_49_parrafo_2.ann -> ejemplo_3_150.ann
# Renamed: articulo_8_parrafo_1.ann -> ejemplo_3_151.ann
# Renamed: articulo_39_parrafo_1.ann -> ejemplo_3_152.ann
# Renamed: articulo_84_parrafo_1.ann -> ejemplo_3_153.ann
# Renamed: articulo_44.ann -> ejemplo_3_154.ann
# Renamed: articulo_52_parrafo_8.ann -> ejemplo_3_155.ann
# Renamed: articulo_78.ann -> ejemplo_3_156.ann
# Renamed: articulo_54_parrafo_2.ann -> ejemplo_3_157.ann
# Renamed: articulo_33_parrafo_1.ann -> ejemplo_3_158.ann
# Renamed: articulo_9.ann -> ejemplo_3_159.ann
# Renamed: articulo_43_parrafo_2.ann -> ejemplo_3_160.ann
# Renamed: articulo_19_parrafo_1.ann -> ejemplo_3_161.ann
# Renamed: articulo_54_parrafo_3.ann -> ejemplo_3_162.ann
# Renamed: articulo_34_parrafo_4.ann -> ejemplo_3_163.ann
# Renamed: articulo_47_parrafo_2.ann -> ejemplo_3_164.ann
# Renamed: articulo_20_parrafo_1.ann -> ejemplo_3_165.ann
# Renamed: articulo_79.ann -> ejemplo_3_166.ann
# Renamed: articulo_51.ann -> ejemplo_3_167.ann
# Renamed: articulo_37_parrafo_1.ann -> ejemplo_3_168.ann
# Renamed: articulo_37_parrafo_3.ann -> ejemplo_3_169.ann
# Renamed: articulo_40_parrafo_4.ann -> ejemplo_3_170.ann
# Renamed: articulo_54_parrafo_1.ann -> ejemplo_3_171.ann
# Renamed: articulo_33_parrafo_2.ann -> ejemplo_3_172.ann
# Renamed: articulo_43_parrafo_1.ann -> ejemplo_3_173.ann
# Renamed: articulo_33_parrafo_3.ann -> ejemplo_3_174.ann
# Renamed: articulo_40_parrafo_5.ann -> ejemplo_3_175.ann
# Renamed: articulo_69_parrafo_1.ann -> ejemplo_3_176.ann
# Renamed: articulo_85.ann -> ejemplo_3_177.ann
# Renamed: articulo_47_parrafo_1.ann -> ejemplo_3_178.ann
# Renamed: articulo_46.ann -> ejemplo_3_179.ann
# Renamed: articulo_37_parrafo_2.ann -> ejemplo_3_180.ann
# Renamed: articulo_50_parrafo_1.ann -> ejemplo_3_181.ann
# Renamed: articulo_37_parrafo_6.ann -> ejemplo_3_182.ann
# Renamed: articulo_34_parrafo_3.ann -> ejemplo_3_183.ann
# Renamed: articulo_81.ann -> ejemplo_3_184.ann
# Renamed: articulo_40_parrafo_1.ann -> ejemplo_3_185.ann
# Renamed: articulo_57_parrafo_1.ann -> ejemplo_3_186.ann
# Renamed: articulo_33_parrafo_6.ann -> ejemplo_3_187.ann
# Renamed: articulo_80.ann -> ejemplo_3_188.ann
# Renamed: articulo_89_parrafo_2.ann -> ejemplo_3_189.ann
# Renamed: articulo_53_parrafo_1.ann -> ejemplo_3_190.ann
# Renamed: articulo_34_parrafo_2.ann -> ejemplo_3_191.ann
# Renamed: intro_parrafo_2.ann -> ejemplo_3_192.ann
# Renamed: articulo_37_parrafo_7.ann -> ejemplo_3_193.ann
# Renamed: articulo_37_parrafo_5.ann -> ejemplo_3_194.ann
# Renamed: articulo_41.ann -> ejemplo_3_195.ann
# Renamed: articulo_55.ann -> ejemplo_3_196.ann
# Renamed: articulo_82.ann -> ejemplo_3_197.ann
# Renamed: articulo_33_parrafo_4.ann -> ejemplo_3_198.ann
# Renamed: articulo_40_parrafo_2.ann -> ejemplo_3_199.ann
# Renamed: articulo_1_parrafo_1.ann -> ejemplo_3_200.ann
# Renamed: articulo_40_parrafo_3.ann -> ejemplo_3_201.ann
# Renamed: articulo_33_parrafo_5.ann -> ejemplo_3_202.ann
# Renamed: articulo_89_parrafo_1.ann -> ejemplo_3_203.ann
# Renamed: articulo_83.ann -> ejemplo_3_204.ann
# Renamed: articulo_34_parrafo_1.ann -> ejemplo_3_205.ann
# Renamed: intro_parrafo_1.ann -> ejemplo_3_206.ann
# Renamed: articulo_23_parrafo_1.ann -> ejemplo_3_207.ann
# Renamed: articulo_37_parrafo_4.ann -> ejemplo_3_208.ann

# %%
display(df_renamed)
# Out:
#                            old                new
# 0    articulo_45_parrafo_1.ann    ejemplo_3_0.ann
# 1              articulo_71.ann    ejemplo_3_1.ann
# 2    articulo_52_parrafo_1.ann    ejemplo_3_2.ann
# 3              articulo_59.ann    ejemplo_3_3.ann
# 4    articulo_42_parrafo_5.ann    ejemplo_3_4.ann
# ..                         ...                ...
# 204            articulo_83.ann  ejemplo_3_204.ann
# 205  articulo_34_parrafo_1.ann  ejemplo_3_205.ann
# 206        intro_parrafo_1.ann  ejemplo_3_206.ann
# 207  articulo_23_parrafo_1.ann  ejemplo_3_207.ann
# 208  articulo_37_parrafo_4.ann  ejemplo_3_208.ann
#
# [209 rows x 2 columns]
